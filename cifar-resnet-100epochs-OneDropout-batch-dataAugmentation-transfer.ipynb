# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
import time

# %%
# baseline model with dropout and data augmentation on the cifar10 dataset
import sys
from matplotlib import pyplot
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dropout
from keras.layers import BatchNormalization
 
# load train and test dataset
def load_dataset():
 # load dataset
 (trainX, trainY), (testX, testY) = cifar10.load_data()
 # one hot encode target values
 trainY = to_categorical(trainY)
 testY = to_categorical(testY)
 return trainX, trainY, testX, testY
 
# scale pixels
def prep_pixels(train, test):
 # convert from integers to floats
 train_norm = train.astype('float32')
 test_norm = test.astype('float32')
 # normalize to range 0-1
 train_norm = train_norm / 255.0
 test_norm = test_norm / 255.0
 # return normalized images
 return train_norm, test_norm
 
# define cnn model
def define_model():
    new_model = Sequential()
    
    model = tf.keras.applications.ResNet50(
        include_top=False,
        weights="imagenet",
        input_tensor=None,
        input_shape=(32,32,3),
        pooling=None,
        classes=10,
       # classifier_activation="softmax",
    #    **kwargs
        )
    
    
    new_model.add(model)
    #3rd conv layer
    new_model.add(tf.keras.layers.Conv2D(32, 3, padding="same"))
    new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.MaxPooling2D(2, padding='same'))
    #4th conv layer
    new_model.add(tf.keras.layers.Conv2D(64, 3, padding="same"))
    new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.MaxPooling2D(2, padding='same'))
    #Flatten Layer
    new_model.add(tf.keras.layers.Flatten())

    new_model.add(tf.keras.layers.Dense(128, kernel_regularizer = tf.keras.regularizers.l2( l=0.01)))
    new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.Dropout(0.2))
    #new_model.add(tf.keras.layers.l2( l=0.01))
    #new_model.add(layers.GlobalAveragePooling2D())
    #output Dense Layer
    new_model.add(tf.keras.layers.Dense(10))
    new_model.add(tf.keras.layers.Activation('softmax'))
    adam = tf.keras.optimizers.Adam(lr=0.001)
    
    opt = SGD(lr=0.001, momentum=0.9)
    new_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return new_model
 
# plot diagnostic learning curves
def summarize_diagnostics(history):
 # plot loss
    model_trained = history
    accuracy = model_trained.history['accuracy']
    val_accuracy = model_trained.history['val_accuracy']
    loss = model_trained.history['loss']
    val_loss = model_trained.history['val_loss']
    epochs = range(len(accuracy))
    plt.plot(epochs, accuracy, 'b', label='Acurácia de treino')
    plt.plot(epochs, val_accuracy, 'g', label='Acurácia de validação')
    plt.title('Acurácia de treino e validação')
    plt.legend()
    plt.figure()
    plt.plot(epochs, loss, 'b', label='Perda no treino')
    plt.plot(epochs, val_loss, 'g', label='Perda na validação')
    plt.title('Perda na validação e treino')
    plt.legend()
    plt.show()
 
# run the test harness for evaluating a model
def run_test_harness(epochs, verb):
 # load dataset
 trainX, trainY, testX, testY = load_dataset()
 # prepare pixel data
 trainX, testX = prep_pixels(trainX, testX)
 # define model
 model = define_model()
 # create data generator
 datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
 # prepare iterator
 it_train = datagen.flow(trainX, trainY, batch_size=64)
 # fit model
 steps = int(trainX.shape[0] / 64)
 history = model.fit(it_train, steps_per_epoch=steps, epochs=epochs, validation_data=(testX, testY), verbose=verb)
 # evaluate model
 _, acc = model.evaluate(testX, testY, verbose=verb)
 print('> %.3f' % (acc * 100.0))
 # learning curves
 summarize_diagnostics(history)

# %%
epochs = 100
verb = 1

# %%
trainX, trainY, testX, testY = load_dataset()
 # prepare pixel data
trainX, testX = prep_pixels(trainX, testX)
 # define model
model = define_model()
 # create data generator
datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True)
 # prepare iterator
it_train = datagen.flow(trainX, trainY, batch_size=64)
 # fit model
steps = int(trainX.shape[0] / 64)
history = model.fit(it_train, steps_per_epoch=steps, epochs=epochs, validation_data=(testX, testY), verbose=verb)
# Out:
# Epoch 1/100
# C:\Users\tmcle\.conda\envs\tf\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# C:\Users\tmcle\.conda\envs\tf\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 781/781 [==============================] - 118s 141ms/step - loss: 2.2266 - accuracy: 0.4809 - val_loss: 2.7593 - val_accuracy: 0.3061
# Epoch 2/100
# 781/781 [==============================] - 106s 135ms/step - loss: 1.4879 - accuracy: 0.6792 - val_loss: 1.2689 - val_accuracy: 0.7213
# Epoch 3/100
# 781/781 [==============================] - 105s 135ms/step - loss: 1.1831 - accuracy: 0.7361 - val_loss: 1.0123 - val_accuracy: 0.7680
# Epoch 4/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.9802 - accuracy: 0.7692 - val_loss: 0.9050 - val_accuracy: 0.7750
# Epoch 5/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.8426 - accuracy: 0.7893 - val_loss: 0.7796 - val_accuracy: 0.7951
# Epoch 6/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.7238 - accuracy: 0.8096 - val_loss: 0.7238 - val_accuracy: 0.7994
# Epoch 7/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.6485 - accuracy: 0.8181 - val_loss: 0.6954 - val_accuracy: 0.7991
# Epoch 8/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.5818 - accuracy: 0.8337 - val_loss: 0.6034 - val_accuracy: 0.8213
# Epoch 9/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.5313 - accuracy: 0.8422 - val_loss: 0.5908 - val_accuracy: 0.8270
# Epoch 10/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.4846 - accuracy: 0.8518 - val_loss: 0.6184 - val_accuracy: 0.8074
# Epoch 11/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.4509 - accuracy: 0.8600 - val_loss: 0.5980 - val_accuracy: 0.8078
# Epoch 12/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.4198 - accuracy: 0.8667 - val_loss: 0.6282 - val_accuracy: 0.8017
# Epoch 13/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.3966 - accuracy: 0.8749 - val_loss: 0.5523 - val_accuracy: 0.8251
# Epoch 14/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.3752 - accuracy: 0.8797 - val_loss: 0.6235 - val_accuracy: 0.8028
# Epoch 15/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.3508 - accuracy: 0.8862 - val_loss: 0.5429 - val_accuracy: 0.8293
# Epoch 16/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.3380 - accuracy: 0.8902 - val_loss: 0.5340 - val_accuracy: 0.8327
# Epoch 17/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.3235 - accuracy: 0.8954 - val_loss: 0.5247 - val_accuracy: 0.8366
# Epoch 18/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.3099 - accuracy: 0.8983 - val_loss: 0.5362 - val_accuracy: 0.8320
# Epoch 19/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.2938 - accuracy: 0.9045 - val_loss: 0.5558 - val_accuracy: 0.8290
# Epoch 20/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.2843 - accuracy: 0.9079 - val_loss: 0.5184 - val_accuracy: 0.8422
# Epoch 21/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.2732 - accuracy: 0.9103 - val_loss: 0.5495 - val_accuracy: 0.8295
# Epoch 22/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.2569 - accuracy: 0.9168 - val_loss: 0.5538 - val_accuracy: 0.8318
# Epoch 23/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.2454 - accuracy: 0.9203 - val_loss: 0.5491 - val_accuracy: 0.8293
# Epoch 24/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.2387 - accuracy: 0.9237 - val_loss: 0.5363 - val_accuracy: 0.8418
# Epoch 25/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.2278 - accuracy: 0.9260 - val_loss: 0.5427 - val_accuracy: 0.8361
# Epoch 26/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.2191 - accuracy: 0.9285 - val_loss: 0.5568 - val_accuracy: 0.8343
# Epoch 27/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.2149 - accuracy: 0.9310 - val_loss: 0.5621 - val_accuracy: 0.8317
# Epoch 28/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1996 - accuracy: 0.9358 - val_loss: 0.6106 - val_accuracy: 0.8273
# Epoch 29/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.1988 - accuracy: 0.9345 - val_loss: 0.5434 - val_accuracy: 0.8426
# Epoch 30/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1932 - accuracy: 0.9375 - val_loss: 0.5459 - val_accuracy: 0.8475
# Epoch 31/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1872 - accuracy: 0.9405 - val_loss: 0.5563 - val_accuracy: 0.8436
# Epoch 32/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1760 - accuracy: 0.9441 - val_loss: 0.5601 - val_accuracy: 0.8408
# Epoch 33/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1733 - accuracy: 0.9446 - val_loss: 0.5722 - val_accuracy: 0.8374
# Epoch 34/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1709 - accuracy: 0.9460 - val_loss: 0.5443 - val_accuracy: 0.8428
# Epoch 35/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1641 - accuracy: 0.9477 - val_loss: 0.5915 - val_accuracy: 0.8361
# Epoch 36/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1617 - accuracy: 0.9480 - val_loss: 0.6102 - val_accuracy: 0.8347
# Epoch 37/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1562 - accuracy: 0.9496 - val_loss: 0.5655 - val_accuracy: 0.8444
# Epoch 38/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1525 - accuracy: 0.9512 - val_loss: 0.5632 - val_accuracy: 0.8425
# Epoch 39/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1420 - accuracy: 0.9549 - val_loss: 0.5613 - val_accuracy: 0.8486
# Epoch 40/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1406 - accuracy: 0.9560 - val_loss: 0.5821 - val_accuracy: 0.8445
# Epoch 41/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1380 - accuracy: 0.9567 - val_loss: 0.6474 - val_accuracy: 0.8229
# Epoch 42/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1329 - accuracy: 0.9581 - val_loss: 0.5653 - val_accuracy: 0.8492
# Epoch 43/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1272 - accuracy: 0.9610 - val_loss: 0.5927 - val_accuracy: 0.8381
# Epoch 44/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1220 - accuracy: 0.9623 - val_loss: 0.5595 - val_accuracy: 0.8500
# Epoch 45/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1254 - accuracy: 0.9614 - val_loss: 0.5606 - val_accuracy: 0.8472
# Epoch 46/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1175 - accuracy: 0.9635 - val_loss: 0.6034 - val_accuracy: 0.8417
# Epoch 47/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1154 - accuracy: 0.9637 - val_loss: 0.5980 - val_accuracy: 0.8435
# Epoch 48/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1140 - accuracy: 0.9641 - val_loss: 0.5903 - val_accuracy: 0.8473
# Epoch 49/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1119 - accuracy: 0.9652 - val_loss: 0.5827 - val_accuracy: 0.8462
# Epoch 50/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1113 - accuracy: 0.9653 - val_loss: 0.6860 - val_accuracy: 0.8245
# Epoch 51/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1043 - accuracy: 0.9677 - val_loss: 0.6363 - val_accuracy: 0.8382
# Epoch 52/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.1024 - accuracy: 0.9695 - val_loss: 0.6040 - val_accuracy: 0.8455
# Epoch 53/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0991 - accuracy: 0.9695 - val_loss: 0.7563 - val_accuracy: 0.8087
# Epoch 54/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0942 - accuracy: 0.9710 - val_loss: 0.5967 - val_accuracy: 0.8510
# Epoch 55/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0989 - accuracy: 0.9701 - val_loss: 0.6224 - val_accuracy: 0.8396
# Epoch 56/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0897 - accuracy: 0.9720 - val_loss: 0.6059 - val_accuracy: 0.8479
# Epoch 57/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0908 - accuracy: 0.9724 - val_loss: 0.6308 - val_accuracy: 0.8367
# Epoch 58/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0912 - accuracy: 0.9727 - val_loss: 0.5699 - val_accuracy: 0.8522
# Epoch 59/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0913 - accuracy: 0.9717 - val_loss: 0.6024 - val_accuracy: 0.8468
# Epoch 60/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0815 - accuracy: 0.9751 - val_loss: 0.5938 - val_accuracy: 0.8538
# Epoch 61/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0879 - accuracy: 0.9735 - val_loss: 0.6642 - val_accuracy: 0.8318
# Epoch 62/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0853 - accuracy: 0.9741 - val_loss: 0.5811 - val_accuracy: 0.8525
# Epoch 63/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0807 - accuracy: 0.9758 - val_loss: 0.7061 - val_accuracy: 0.8242
# Epoch 64/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0876 - accuracy: 0.9731 - val_loss: 0.6045 - val_accuracy: 0.8442
# Epoch 65/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0821 - accuracy: 0.9756 - val_loss: 0.6240 - val_accuracy: 0.8427
# Epoch 66/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0787 - accuracy: 0.9758 - val_loss: 0.6224 - val_accuracy: 0.8449
# Epoch 67/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0796 - accuracy: 0.9759 - val_loss: 0.5994 - val_accuracy: 0.8463
# Epoch 68/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0751 - accuracy: 0.9771 - val_loss: 0.6251 - val_accuracy: 0.8496
# Epoch 69/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0759 - accuracy: 0.9778 - val_loss: 0.6755 - val_accuracy: 0.8363
# Epoch 70/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0713 - accuracy: 0.9785 - val_loss: 0.6196 - val_accuracy: 0.8529
# Epoch 71/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0689 - accuracy: 0.9799 - val_loss: 0.6011 - val_accuracy: 0.8596
# Epoch 72/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0698 - accuracy: 0.9796 - val_loss: 0.6285 - val_accuracy: 0.8496
# Epoch 73/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0681 - accuracy: 0.9793 - val_loss: 0.6122 - val_accuracy: 0.8547
# Epoch 74/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0680 - accuracy: 0.9798 - val_loss: 0.6494 - val_accuracy: 0.8422
# Epoch 75/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0654 - accuracy: 0.9802 - val_loss: 0.6110 - val_accuracy: 0.8570
# Epoch 76/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0675 - accuracy: 0.9795 - val_loss: 0.6006 - val_accuracy: 0.8548
# Epoch 77/100
# 781/781 [==============================] - 105s 135ms/step - loss: 0.0673 - accuracy: 0.9800 - val_loss: 0.6625 - val_accuracy: 0.8437
# Epoch 78/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0607 - accuracy: 0.9830 - val_loss: 0.6270 - val_accuracy: 0.8536
# Epoch 79/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0648 - accuracy: 0.9809 - val_loss: 0.6200 - val_accuracy: 0.8510
# Epoch 80/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0596 - accuracy: 0.9822 - val_loss: 0.6718 - val_accuracy: 0.8440
# Epoch 81/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0634 - accuracy: 0.9812 - val_loss: 0.6292 - val_accuracy: 0.8534
# Epoch 82/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0582 - accuracy: 0.9826 - val_loss: 0.6053 - val_accuracy: 0.8595
# Epoch 83/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0555 - accuracy: 0.9835 - val_loss: 0.6572 - val_accuracy: 0.8466
# Epoch 84/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0586 - accuracy: 0.9822 - val_loss: 0.6337 - val_accuracy: 0.8524
# Epoch 85/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0583 - accuracy: 0.9831 - val_loss: 0.6172 - val_accuracy: 0.8557
# Epoch 86/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0561 - accuracy: 0.9833 - val_loss: 0.6273 - val_accuracy: 0.8568
# Epoch 87/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0560 - accuracy: 0.9836 - val_loss: 0.6152 - val_accuracy: 0.8572
# Epoch 88/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0538 - accuracy: 0.9844 - val_loss: 0.6437 - val_accuracy: 0.8527
# Epoch 89/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0538 - accuracy: 0.9840 - val_loss: 0.6532 - val_accuracy: 0.8492
# Epoch 90/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0543 - accuracy: 0.9842 - val_loss: 0.6576 - val_accuracy: 0.8483
# Epoch 91/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0546 - accuracy: 0.9835 - val_loss: 0.6668 - val_accuracy: 0.8519
# Epoch 92/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0553 - accuracy: 0.9837 - val_loss: 0.6307 - val_accuracy: 0.8538
# Epoch 93/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0507 - accuracy: 0.9851 - val_loss: 0.6620 - val_accuracy: 0.8517
# Epoch 94/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0504 - accuracy: 0.9850 - val_loss: 0.6285 - val_accuracy: 0.8560
# Epoch 95/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0506 - accuracy: 0.9849 - val_loss: 0.6422 - val_accuracy: 0.8521
# Epoch 96/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0522 - accuracy: 0.9850 - val_loss: 0.6300 - val_accuracy: 0.8563
# Epoch 97/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0504 - accuracy: 0.9858 - val_loss: 0.6212 - val_accuracy: 0.8567
# Epoch 98/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0494 - accuracy: 0.9852 - val_loss: 0.6279 - val_accuracy: 0.8585
# Epoch 99/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0493 - accuracy: 0.9856 - val_loss: 0.6646 - val_accuracy: 0.8531
# Epoch 100/100
# 781/781 [==============================] - 105s 134ms/step - loss: 0.0478 - accuracy: 0.9863 - val_loss: 0.6539 - val_accuracy: 0.8520

# %%
 # evaluate model
_, acc = model.evaluate(testX, testY, verbose=verb)
print('Acurácia: %.3f' % (acc * 100.0))
# Out:
# 313/313 [==============================] - 8s 27ms/step - loss: 0.6539 - accuracy: 0.8520
# Acurácia: 85.200

# %%
 # learning curves
summarize_diagnostics(history)

# %%
model_name = f'cifar-resnet50-baseline-holdout-{epochs}epochs_all_transfer.npy'
model.save(model_name)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 55). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cifar-resnet50-baseline-holdout-100epochs_all_transfer.npy\assets
# INFO:tensorflow:Assets written to: cifar-resnet50-baseline-holdout-100epochs_all_transfer.npy\assets

# %%
# entry point, run the test harness
#run_test_harness(epochs=100, verb=1)
