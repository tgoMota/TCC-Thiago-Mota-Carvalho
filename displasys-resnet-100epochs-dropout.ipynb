# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
import time
import numpy as np

# %%
# baseline model with dropout and data augmentation on the cifar10 dataset
import sys
from matplotlib import pyplot
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dropout
from keras.layers import BatchNormalization

# %%
# load train and test dataset
def load_dataset():
    # load dataset
    data_x = np.load('data_x_original.npy')
    data_y = np.load('data_y_original.npy')
    #percentage of the dataset which will be on TRAIN - TEST - VALIDATION
    TOTAL_IMAGES = len(data_y)
    print("TOTAL_IMAGES = ", TOTAL_IMAGES)
    
    TRAIN_PERCENTAGE = 0.8
    TEST_PERCENTAGE = 0.1
    VALIDATION_PERCENTAGE = 0.1

    train_size = int(TRAIN_PERCENTAGE * TOTAL_IMAGES)
    test_size = int(TEST_PERCENTAGE * TOTAL_IMAGES)
    validation_size = int(VALIDATION_PERCENTAGE * TOTAL_IMAGES)

    train_x = data_x[:train_size] #taking train images from original data
    train_y = data_y[:train_size]
    data_x = data_x[train_size:] #removing train images from original data
    data_y = data_y[train_size:]

    test_x = data_x[:test_size] #taking test images from original data
    test_y = data_y[:test_size]
    data_x = data_x[test_size:] #removing test images from original data
    data_y = data_y[test_size:]

    validation_x = data_x #all the remainder images we can put on validation
    validation_y = data_y

    del data_x #free some unused memory
    del data_y

    print("train_size = ", len(train_y))
    print("test_size = ", len(test_y))
    print("validation_size = ", len(validation_y))
 # one hot encode target values
    train_y = to_categorical(train_y)
    test_y = to_categorical(test_y)
    validation_y = to_categorical(validation_y)
    return train_x, train_y, test_x, test_y, validation_x, validation_y

# %%
# scale pixels
def prep_pixels(train, test, validation):
 # convert from integers to floats
 train_norm = train.astype('float32')
 test_norm = test.astype('float32')
 validation_norm = validation.astype('float32')
 # normalize to range 0-1
 train_norm = train_norm / 255.0
 test_norm = test_norm / 255.0
 validation_norm = validation_norm / 255.0
 # return normalized images
 return train_norm, test_norm, validation_norm

# %%
# define cnn model
def define_model():
    new_model = Sequential()
    
    model = tf.keras.applications.ResNet50(
        include_top=False,
        weights=None,
        input_tensor=None,
        input_shape=(128,128,3),
        pooling=None,
        classes=4,
       # classifier_activation="softmax",
    #    **kwargs
        )
    
    new_model.add(model)
    #3rd conv layer
    new_model.add(tf.keras.layers.Conv2D(32, 3, padding="same"))
    #new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.MaxPooling2D(2, padding='same'))
    new_model.add(tf.keras.layers.Dropout(0.2))
    #4th conv layer
    new_model.add(tf.keras.layers.Conv2D(64, 3, padding="same"))
    #new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.MaxPooling2D(2, padding='same'))
    new_model.add(tf.keras.layers.Dropout(0.2))
    #Flatten Layer
    new_model.add(tf.keras.layers.Flatten())

    new_model.add(tf.keras.layers.Dense(128))
    #new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.Dropout(0.2))
    #output Dense Layer
    new_model.add(tf.keras.layers.Dense(4))
    new_model.add(tf.keras.layers.Activation('softmax'))
    
    opt = SGD(lr=0.001, momentum=0.9)
    new_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return new_model

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
 # plot loss
    model_trained = history
    accuracy = model_trained.history['accuracy']
    val_accuracy = model_trained.history['val_accuracy']
    loss = model_trained.history['loss']
    val_loss = model_trained.history['val_loss']
    epochs = range(len(accuracy))
    plt.plot(epochs, accuracy, 'b', label='Acurácia de treino')
    plt.plot(epochs, val_accuracy, 'g', label='Acurácia de validação')
    plt.title('Acurácia de treino e validação')
    plt.legend()
    plt.figure()
    plt.plot(epochs, loss, 'b', label='Perda no treino')
    plt.plot(epochs, val_loss, 'g', label='Perda na validação')
    plt.title('Perda na validação e treino')
    plt.legend()
    plt.show()

# %%
epochs = 100
verb = 2

# %%
trainX, trainY, testX, testY, validationX, validationY = load_dataset()
 # prepare pixel data
trainX, testX, validationX = prep_pixels(trainX, testX, validationX)
 # define model
model = define_model()

history = model.fit(trainX, trainY, epochs=epochs, validation_data=(validationX, validationY), verbose=verb)
# Out:
# TOTAL_IMAGES =  592
# train_size =  473
# test_size =  59
# validation_size =  60
# Epoch 1/100
# 15/15 - 15s - loss: 1.6514 - accuracy: 0.2347 - val_loss: 1.3872 - val_accuracy: 0.2167 - 15s/epoch - 977ms/step
# Epoch 2/100
# 15/15 - 4s - loss: 1.4095 - accuracy: 0.2495 - val_loss: 1.3880 - val_accuracy: 0.2167 - 4s/epoch - 282ms/step
# Epoch 3/100
# 15/15 - 4s - loss: 1.3613 - accuracy: 0.2854 - val_loss: 1.3877 - val_accuracy: 0.2167 - 4s/epoch - 281ms/step
# Epoch 4/100
# 15/15 - 4s - loss: 1.3618 - accuracy: 0.3087 - val_loss: 1.3878 - val_accuracy: 0.2167 - 4s/epoch - 283ms/step
# Epoch 5/100
# 15/15 - 4s - loss: 1.3454 - accuracy: 0.3425 - val_loss: 1.3879 - val_accuracy: 0.2167 - 4s/epoch - 283ms/step
# Epoch 6/100
# 15/15 - 4s - loss: 1.3218 - accuracy: 0.3636 - val_loss: 1.3887 - val_accuracy: 0.2167 - 4s/epoch - 283ms/step
# Epoch 7/100
# 15/15 - 4s - loss: 1.3015 - accuracy: 0.3510 - val_loss: 1.3881 - val_accuracy: 0.2167 - 4s/epoch - 283ms/step
# Epoch 8/100
# 15/15 - 4s - loss: 1.2892 - accuracy: 0.3573 - val_loss: 1.3882 - val_accuracy: 0.2167 - 4s/epoch - 283ms/step
# Epoch 9/100
# 15/15 - 4s - loss: 1.2818 - accuracy: 0.3721 - val_loss: 1.3883 - val_accuracy: 0.2167 - 4s/epoch - 283ms/step
# Epoch 10/100
# 15/15 - 4s - loss: 1.2368 - accuracy: 0.3996 - val_loss: 1.3885 - val_accuracy: 0.2167 - 4s/epoch - 283ms/step
# Epoch 11/100
# 15/15 - 4s - loss: 1.2390 - accuracy: 0.3932 - val_loss: 1.3886 - val_accuracy: 0.2167 - 4s/epoch - 283ms/step
# Epoch 12/100
# 15/15 - 4s - loss: 1.2071 - accuracy: 0.4080 - val_loss: 1.3885 - val_accuracy: 0.2167 - 4s/epoch - 283ms/step
# Epoch 13/100
# 15/15 - 4s - loss: 1.2154 - accuracy: 0.4080 - val_loss: 1.3890 - val_accuracy: 0.2167 - 4s/epoch - 283ms/step
# Epoch 14/100
# 15/15 - 4s - loss: 1.2060 - accuracy: 0.4186 - val_loss: 1.3894 - val_accuracy: 0.2167 - 4s/epoch - 282ms/step
# Epoch 15/100
# 15/15 - 4s - loss: 1.1615 - accuracy: 0.4419 - val_loss: 1.3897 - val_accuracy: 0.2167 - 4s/epoch - 283ms/step
# Epoch 16/100
# 15/15 - 4s - loss: 1.1538 - accuracy: 0.4545 - val_loss: 1.3906 - val_accuracy: 0.2167 - 4s/epoch - 287ms/step
# Epoch 17/100
# 15/15 - 4s - loss: 1.1542 - accuracy: 0.4461 - val_loss: 1.3915 - val_accuracy: 0.2167 - 4s/epoch - 290ms/step
# Epoch 18/100
# 15/15 - 4s - loss: 1.1305 - accuracy: 0.4630 - val_loss: 1.3922 - val_accuracy: 0.2167 - 4s/epoch - 296ms/step
# Epoch 19/100
# 15/15 - 4s - loss: 1.1402 - accuracy: 0.4884 - val_loss: 1.3934 - val_accuracy: 0.2167 - 4s/epoch - 298ms/step
# Epoch 20/100
# 15/15 - 4s - loss: 1.0963 - accuracy: 0.5053 - val_loss: 1.3937 - val_accuracy: 0.2167 - 4s/epoch - 288ms/step
# Epoch 21/100
# 15/15 - 4s - loss: 1.0573 - accuracy: 0.5539 - val_loss: 1.3943 - val_accuracy: 0.1500 - 4s/epoch - 288ms/step
# Epoch 22/100
# 15/15 - 4s - loss: 1.0266 - accuracy: 0.5518 - val_loss: 1.3966 - val_accuracy: 0.2000 - 4s/epoch - 294ms/step
# Epoch 23/100
# 15/15 - 4s - loss: 0.9944 - accuracy: 0.5793 - val_loss: 1.4016 - val_accuracy: 0.2167 - 4s/epoch - 289ms/step
# Epoch 24/100
# 15/15 - 4s - loss: 0.9747 - accuracy: 0.5708 - val_loss: 1.4060 - val_accuracy: 0.2167 - 4s/epoch - 288ms/step
# Epoch 25/100
# 15/15 - 4s - loss: 0.9490 - accuracy: 0.5983 - val_loss: 1.3797 - val_accuracy: 0.3000 - 4s/epoch - 284ms/step
# Epoch 26/100
# 15/15 - 4s - loss: 0.9505 - accuracy: 0.5920 - val_loss: 1.3821 - val_accuracy: 0.3333 - 4s/epoch - 295ms/step
# Epoch 27/100
# 15/15 - 4s - loss: 0.9143 - accuracy: 0.6385 - val_loss: 1.6217 - val_accuracy: 0.2167 - 4s/epoch - 296ms/step
# Epoch 28/100
# 15/15 - 4s - loss: 0.9284 - accuracy: 0.5856 - val_loss: 1.4425 - val_accuracy: 0.1667 - 4s/epoch - 288ms/step
# Epoch 29/100
# 15/15 - 4s - loss: 0.8871 - accuracy: 0.6216 - val_loss: 1.3855 - val_accuracy: 0.3000 - 4s/epoch - 284ms/step
# Epoch 30/100
# 15/15 - 4s - loss: 0.8536 - accuracy: 0.6279 - val_loss: 1.4566 - val_accuracy: 0.3000 - 4s/epoch - 286ms/step
# Epoch 31/100
# 15/15 - 4s - loss: 0.8560 - accuracy: 0.6427 - val_loss: 1.4373 - val_accuracy: 0.1167 - 4s/epoch - 288ms/step
# Epoch 32/100
# 15/15 - 4s - loss: 0.8249 - accuracy: 0.6364 - val_loss: 1.4399 - val_accuracy: 0.2333 - 4s/epoch - 288ms/step
# Epoch 33/100
# 15/15 - 4s - loss: 0.8800 - accuracy: 0.6068 - val_loss: 1.4540 - val_accuracy: 0.2167 - 4s/epoch - 284ms/step
# Epoch 34/100
# 15/15 - 4s - loss: 0.8734 - accuracy: 0.6195 - val_loss: 1.4419 - val_accuracy: 0.1500 - 4s/epoch - 286ms/step
# Epoch 35/100
# 15/15 - 4s - loss: 1.0532 - accuracy: 0.5645 - val_loss: 1.4651 - val_accuracy: 0.2167 - 4s/epoch - 284ms/step
# Epoch 36/100
# 15/15 - 4s - loss: 1.0003 - accuracy: 0.5624 - val_loss: 1.6543 - val_accuracy: 0.2167 - 4s/epoch - 284ms/step
# Epoch 37/100
# 15/15 - 4s - loss: 0.9381 - accuracy: 0.5814 - val_loss: 1.7183 - val_accuracy: 0.2167 - 4s/epoch - 286ms/step
# Epoch 38/100
# 15/15 - 4s - loss: 0.8017 - accuracy: 0.6744 - val_loss: 1.6510 - val_accuracy: 0.2667 - 4s/epoch - 287ms/step
# Epoch 39/100
# 15/15 - 4s - loss: 0.7925 - accuracy: 0.6406 - val_loss: 1.4594 - val_accuracy: 0.2333 - 4s/epoch - 285ms/step
# Epoch 40/100
# 15/15 - 4s - loss: 0.7977 - accuracy: 0.6596 - val_loss: 1.4970 - val_accuracy: 0.1500 - 4s/epoch - 284ms/step
# Epoch 41/100
# 15/15 - 4s - loss: 0.7713 - accuracy: 0.6575 - val_loss: 1.3660 - val_accuracy: 0.2167 - 4s/epoch - 285ms/step
# Epoch 42/100
# 15/15 - 4s - loss: 0.7129 - accuracy: 0.6596 - val_loss: 1.4278 - val_accuracy: 0.2833 - 4s/epoch - 284ms/step
# Epoch 43/100
# 15/15 - 4s - loss: 0.6683 - accuracy: 0.6956 - val_loss: 1.5793 - val_accuracy: 0.1500 - 4s/epoch - 284ms/step
# Epoch 44/100
# 15/15 - 4s - loss: 0.6426 - accuracy: 0.7061 - val_loss: 1.9617 - val_accuracy: 0.2833 - 4s/epoch - 284ms/step
# Epoch 45/100
# 15/15 - 4s - loss: 0.6137 - accuracy: 0.7252 - val_loss: 1.6320 - val_accuracy: 0.1333 - 4s/epoch - 284ms/step
# Epoch 46/100
# 15/15 - 4s - loss: 0.6096 - accuracy: 0.7061 - val_loss: 1.5533 - val_accuracy: 0.1667 - 4s/epoch - 284ms/step
# Epoch 47/100
# 15/15 - 4s - loss: 0.6006 - accuracy: 0.7230 - val_loss: 1.5759 - val_accuracy: 0.2000 - 4s/epoch - 284ms/step
# Epoch 48/100
# 15/15 - 4s - loss: 0.5541 - accuracy: 0.7484 - val_loss: 1.5033 - val_accuracy: 0.2333 - 4s/epoch - 285ms/step
# Epoch 49/100
# 15/15 - 4s - loss: 0.5550 - accuracy: 0.7357 - val_loss: 1.5870 - val_accuracy: 0.2167 - 4s/epoch - 286ms/step
# Epoch 50/100
# 15/15 - 4s - loss: 0.5228 - accuracy: 0.7146 - val_loss: 1.5230 - val_accuracy: 0.2000 - 4s/epoch - 287ms/step
# Epoch 51/100
# 15/15 - 4s - loss: 0.5706 - accuracy: 0.7252 - val_loss: 1.6702 - val_accuracy: 0.1500 - 4s/epoch - 285ms/step
# Epoch 52/100
# 15/15 - 4s - loss: 0.5575 - accuracy: 0.7273 - val_loss: 1.5469 - val_accuracy: 0.2167 - 4s/epoch - 285ms/step
# Epoch 53/100
# 15/15 - 4s - loss: 0.5245 - accuracy: 0.7569 - val_loss: 1.6201 - val_accuracy: 0.2333 - 4s/epoch - 286ms/step
# Epoch 54/100
# 15/15 - 4s - loss: 0.6254 - accuracy: 0.7336 - val_loss: 1.6702 - val_accuracy: 0.2500 - 4s/epoch - 285ms/step
# Epoch 55/100
# 15/15 - 4s - loss: 0.5434 - accuracy: 0.8140 - val_loss: 2.0236 - val_accuracy: 0.2333 - 4s/epoch - 285ms/step
# Epoch 56/100
# 15/15 - 4s - loss: 0.5202 - accuracy: 0.8245 - val_loss: 1.7517 - val_accuracy: 0.2333 - 4s/epoch - 285ms/step
# Epoch 57/100
# 15/15 - 4s - loss: 0.5017 - accuracy: 0.8140 - val_loss: 1.6833 - val_accuracy: 0.2500 - 4s/epoch - 285ms/step
# Epoch 58/100
# 15/15 - 4s - loss: 0.4969 - accuracy: 0.8288 - val_loss: 1.7051 - val_accuracy: 0.2500 - 4s/epoch - 285ms/step
# Epoch 59/100
# 15/15 - 4s - loss: 0.4609 - accuracy: 0.8330 - val_loss: 1.7143 - val_accuracy: 0.2333 - 4s/epoch - 285ms/step
# Epoch 60/100
# 15/15 - 4s - loss: 0.4347 - accuracy: 0.8499 - val_loss: 1.7337 - val_accuracy: 0.2667 - 4s/epoch - 285ms/step
# Epoch 61/100
# 15/15 - 4s - loss: 0.4639 - accuracy: 0.8351 - val_loss: 1.6827 - val_accuracy: 0.2833 - 4s/epoch - 284ms/step
# Epoch 62/100
# 15/15 - 4s - loss: 0.4607 - accuracy: 0.8499 - val_loss: 1.7413 - val_accuracy: 0.2667 - 4s/epoch - 285ms/step
# Epoch 63/100
# 15/15 - 4s - loss: 0.4375 - accuracy: 0.8584 - val_loss: 1.6838 - val_accuracy: 0.2667 - 4s/epoch - 285ms/step
# Epoch 64/100
# 15/15 - 4s - loss: 0.4384 - accuracy: 0.8499 - val_loss: 1.5411 - val_accuracy: 0.3333 - 4s/epoch - 286ms/step
# Epoch 65/100
# 15/15 - 4s - loss: 0.4159 - accuracy: 0.8689 - val_loss: 1.5068 - val_accuracy: 0.3500 - 4s/epoch - 285ms/step
# Epoch 66/100
# 15/15 - 4s - loss: 0.4673 - accuracy: 0.8393 - val_loss: 1.5709 - val_accuracy: 0.3000 - 4s/epoch - 285ms/step
# Epoch 67/100
# 15/15 - 4s - loss: 0.4081 - accuracy: 0.8605 - val_loss: 1.4781 - val_accuracy: 0.4167 - 4s/epoch - 286ms/step
# Epoch 68/100
# 15/15 - 4s - loss: 0.4300 - accuracy: 0.8584 - val_loss: 1.4147 - val_accuracy: 0.4000 - 4s/epoch - 286ms/step
# Epoch 69/100
# 15/15 - 4s - loss: 0.3786 - accuracy: 0.8541 - val_loss: 1.4385 - val_accuracy: 0.3333 - 4s/epoch - 285ms/step
# Epoch 70/100
# 15/15 - 4s - loss: 0.3751 - accuracy: 0.8732 - val_loss: 1.3490 - val_accuracy: 0.4000 - 4s/epoch - 285ms/step
# Epoch 71/100
# 15/15 - 4s - loss: 0.3241 - accuracy: 0.8985 - val_loss: 1.4530 - val_accuracy: 0.4167 - 4s/epoch - 286ms/step
# Epoch 72/100
# 15/15 - 4s - loss: 0.3688 - accuracy: 0.8774 - val_loss: 1.4005 - val_accuracy: 0.3667 - 4s/epoch - 285ms/step
# Epoch 73/100
# 15/15 - 4s - loss: 0.3672 - accuracy: 0.8964 - val_loss: 1.4876 - val_accuracy: 0.4167 - 4s/epoch - 285ms/step
# Epoch 74/100
# 15/15 - 4s - loss: 0.3702 - accuracy: 0.8774 - val_loss: 1.4597 - val_accuracy: 0.5167 - 4s/epoch - 286ms/step
# Epoch 75/100
# 15/15 - 4s - loss: 0.3344 - accuracy: 0.9112 - val_loss: 1.5468 - val_accuracy: 0.4833 - 4s/epoch - 285ms/step
# Epoch 76/100
# 15/15 - 4s - loss: 0.4037 - accuracy: 0.8668 - val_loss: 1.7168 - val_accuracy: 0.4167 - 4s/epoch - 284ms/step
# Epoch 77/100
# 15/15 - 4s - loss: 0.3698 - accuracy: 0.8753 - val_loss: 1.4662 - val_accuracy: 0.5000 - 4s/epoch - 285ms/step
# Epoch 78/100
# 15/15 - 4s - loss: 0.3726 - accuracy: 0.8774 - val_loss: 1.7708 - val_accuracy: 0.4833 - 4s/epoch - 285ms/step
# Epoch 79/100
# 15/15 - 4s - loss: 0.3919 - accuracy: 0.8753 - val_loss: 1.4452 - val_accuracy: 0.6000 - 4s/epoch - 286ms/step
# Epoch 80/100
# 15/15 - 4s - loss: 0.2996 - accuracy: 0.8964 - val_loss: 1.3886 - val_accuracy: 0.6333 - 4s/epoch - 286ms/step
# Epoch 81/100
# 15/15 - 4s - loss: 0.2876 - accuracy: 0.9070 - val_loss: 1.6989 - val_accuracy: 0.6000 - 4s/epoch - 286ms/step
# Epoch 82/100
# 15/15 - 4s - loss: 0.2831 - accuracy: 0.9027 - val_loss: 1.8954 - val_accuracy: 0.6333 - 4s/epoch - 286ms/step
# Epoch 83/100
# 15/15 - 4s - loss: 0.2773 - accuracy: 0.9133 - val_loss: 1.7962 - val_accuracy: 0.6500 - 4s/epoch - 286ms/step
# Epoch 84/100
# 15/15 - 4s - loss: 0.2556 - accuracy: 0.9091 - val_loss: 1.6519 - val_accuracy: 0.6333 - 4s/epoch - 287ms/step
# Epoch 85/100
# 15/15 - 4s - loss: 0.2969 - accuracy: 0.9239 - val_loss: 1.8537 - val_accuracy: 0.6833 - 4s/epoch - 286ms/step
# Epoch 86/100
# 15/15 - 4s - loss: 0.2494 - accuracy: 0.9175 - val_loss: 3.0648 - val_accuracy: 0.6333 - 4s/epoch - 285ms/step
# Epoch 87/100
# 15/15 - 4s - loss: 0.2960 - accuracy: 0.9197 - val_loss: 1.6192 - val_accuracy: 0.6333 - 4s/epoch - 286ms/step
# Epoch 88/100
# 15/15 - 4s - loss: 0.2556 - accuracy: 0.9049 - val_loss: 1.9012 - val_accuracy: 0.6000 - 4s/epoch - 286ms/step
# Epoch 89/100
# 15/15 - 4s - loss: 0.2262 - accuracy: 0.9218 - val_loss: 2.6019 - val_accuracy: 0.6000 - 4s/epoch - 286ms/step
# Epoch 90/100
# 15/15 - 4s - loss: 0.2383 - accuracy: 0.9218 - val_loss: 1.7608 - val_accuracy: 0.6500 - 4s/epoch - 286ms/step
# Epoch 91/100
# 15/15 - 4s - loss: 0.2355 - accuracy: 0.9197 - val_loss: 1.7935 - val_accuracy: 0.6500 - 4s/epoch - 287ms/step
# Epoch 92/100
# 15/15 - 4s - loss: 0.1931 - accuracy: 0.9450 - val_loss: 2.4205 - val_accuracy: 0.6333 - 4s/epoch - 286ms/step
# Epoch 93/100
# 15/15 - 4s - loss: 0.2535 - accuracy: 0.9218 - val_loss: 2.9497 - val_accuracy: 0.6667 - 4s/epoch - 286ms/step
# Epoch 94/100
# 15/15 - 4s - loss: 0.2261 - accuracy: 0.9302 - val_loss: 2.9844 - val_accuracy: 0.6500 - 4s/epoch - 287ms/step
# Epoch 95/100
# 15/15 - 4s - loss: 0.2436 - accuracy: 0.9345 - val_loss: 1.8511 - val_accuracy: 0.5667 - 4s/epoch - 285ms/step
# Epoch 96/100
# 15/15 - 4s - loss: 0.1908 - accuracy: 0.9408 - val_loss: 1.7870 - val_accuracy: 0.5833 - 4s/epoch - 287ms/step
# Epoch 97/100
# 15/15 - 4s - loss: 0.2084 - accuracy: 0.9239 - val_loss: 2.0969 - val_accuracy: 0.6167 - 4s/epoch - 286ms/step
# Epoch 98/100
# 15/15 - 4s - loss: 0.2299 - accuracy: 0.9239 - val_loss: 1.8100 - val_accuracy: 0.5667 - 4s/epoch - 287ms/step
# Epoch 99/100
# 15/15 - 4s - loss: 0.2005 - accuracy: 0.9345 - val_loss: 1.6239 - val_accuracy: 0.5333 - 4s/epoch - 286ms/step
# Epoch 100/100
# 15/15 - 4s - loss: 0.2710 - accuracy: 0.9218 - val_loss: 2.5814 - val_accuracy: 0.5667 - 4s/epoch - 286ms/step

# %%
 # evaluate model
_, acc = model.evaluate(testX, testY, verbose=verb)
print('Acurácia: %.3f' % (acc * 100.0))
# Out:
# 2/2 - 1s - loss: 2.4135 - accuracy: 0.4915 - 663ms/epoch - 332ms/step
# Acurácia: 49.153

# %%
 # learning curves
summarize_diagnostics(history)

# %%
model_name = f'displasys-resnet50-baseline-holdout-{epochs}epochs_dropout.npy'
model.save(model_name)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 55). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: displasys-resnet50-baseline-holdout-100epochs_dropout.npy\assets
# INFO:tensorflow:Assets written to: displasys-resnet50-baseline-holdout-100epochs_dropout.npy\assets

# %%
# entry point, run the test harness
#run_test_harness(epochs=100, verb=1)
