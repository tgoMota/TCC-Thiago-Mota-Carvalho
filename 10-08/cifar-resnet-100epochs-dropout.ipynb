# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
import time

# %%
# baseline model with dropout and data augmentation on the cifar10 dataset
import sys
from matplotlib import pyplot
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dropout
from keras.layers import BatchNormalization

# %%
# load train and test dataset
def load_dataset():
 # load dataset
 (trainX, trainY), (testX, testY) = cifar10.load_data()
 # one hot encode target values
 trainY = to_categorical(trainY)
 testY = to_categorical(testY)
 return trainX, trainY, testX, testY

# %%
# scale pixels
def prep_pixels(train, test):
 # convert from integers to floats
 train_norm = train.astype('float32')
 test_norm = test.astype('float32')
 # normalize to range 0-1
 train_norm = train_norm / 255.0
 test_norm = test_norm / 255.0
 # return normalized images
 return train_norm, test_norm

# %%
# define cnn model
def define_model():
    new_model = Sequential()
    
    model = tf.keras.applications.ResNet50(
        include_top=False,
        weights=None,
        input_tensor=None,
        input_shape=(32,32,3),
        pooling=None,
        classes=10,
       # classifier_activation="softmax",
    #    **kwargs
        )
    
    
    new_model.add(model)
    #3rd conv layer
    new_model.add(tf.keras.layers.Conv2D(32, 3, padding="same"))
    #new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.MaxPooling2D(2, padding='same'))
    new_model.add(tf.keras.layers.Dropout(0.2))
    #4th conv layer
    new_model.add(tf.keras.layers.Conv2D(64, 3, padding="same"))
    #new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.MaxPooling2D(2, padding='same'))
    new_model.add(tf.keras.layers.Dropout(0.2))
    #Flatten Layer
    new_model.add(tf.keras.layers.Flatten())

    new_model.add(tf.keras.layers.Dense(128))
    #new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.Dropout(0.2))
    #output Dense Layer
    new_model.add(tf.keras.layers.Dense(10))
    new_model.add(tf.keras.layers.Activation('softmax'))
    
    opt = SGD(lr=0.001, momentum=0.9)
    new_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return new_model

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
 # plot loss
    model_trained = history
    accuracy = model_trained.history['accuracy']
    val_accuracy = model_trained.history['val_accuracy']
    loss = model_trained.history['loss']
    val_loss = model_trained.history['val_loss']
    epochs = range(len(accuracy))
    plt.plot(epochs, accuracy, 'b', label='Acurácia de treino')
    plt.plot(epochs, val_accuracy, 'g', label='Acurácia de validação')
    plt.title('Acurácia de treino e validação')
    plt.legend()
    plt.figure()
    plt.plot(epochs, loss, 'b', label='Perda no treino')
    plt.plot(epochs, val_loss, 'g', label='Perda na validação')
    plt.title('Perda na validação e treino')
    plt.legend()
    plt.show()

# %%
epochs = 100
verb = 2

# %%
trainX, trainY, testX, testY = load_dataset()
 # prepare pixel data
trainX, testX = prep_pixels(trainX, testX)
 # define model
model = define_model()

history = model.fit(trainX, trainY, epochs=epochs, validation_data=(testX, testY), verbose=verb)
# Out:
# C:\Users\tmcle\.conda\envs\tf\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:111: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/100
# 1563/1563 - 159s - loss: 2.0928 - accuracy: 0.1914 - val_loss: 1.8473 - val_accuracy: 0.2869 - 159s/epoch - 101ms/step
# Epoch 2/100
# 1563/1563 - 147s - loss: 1.7656 - accuracy: 0.3249 - val_loss: 1.6286 - val_accuracy: 0.3946 - 147s/epoch - 94ms/step
# Epoch 3/100
# 1563/1563 - 148s - loss: 1.6023 - accuracy: 0.4130 - val_loss: 1.7336 - val_accuracy: 0.3790 - 148s/epoch - 94ms/step
# Epoch 4/100
# 1563/1563 - 147s - loss: 1.4867 - accuracy: 0.4686 - val_loss: 1.3500 - val_accuracy: 0.5119 - 147s/epoch - 94ms/step
# Epoch 5/100
# 1563/1563 - 149s - loss: 1.3820 - accuracy: 0.5105 - val_loss: 1.3202 - val_accuracy: 0.5281 - 149s/epoch - 95ms/step
# Epoch 6/100
# 1563/1563 - 149s - loss: 1.2923 - accuracy: 0.5465 - val_loss: 1.3059 - val_accuracy: 0.5414 - 149s/epoch - 95ms/step
# Epoch 7/100
# 1563/1563 - 148s - loss: 1.2051 - accuracy: 0.5786 - val_loss: 1.4280 - val_accuracy: 0.5103 - 148s/epoch - 95ms/step
# Epoch 8/100
# 1563/1563 - 147s - loss: 1.1309 - accuracy: 0.6120 - val_loss: 1.2549 - val_accuracy: 0.5675 - 147s/epoch - 94ms/step
# Epoch 9/100
# 1563/1563 - 147s - loss: 1.0484 - accuracy: 0.6396 - val_loss: 1.1811 - val_accuracy: 0.5872 - 147s/epoch - 94ms/step
# Epoch 10/100
# 1563/1563 - 147s - loss: 0.9799 - accuracy: 0.6663 - val_loss: 1.2028 - val_accuracy: 0.5838 - 147s/epoch - 94ms/step
# Epoch 11/100
# 1563/1563 - 146s - loss: 0.9092 - accuracy: 0.6899 - val_loss: 1.2608 - val_accuracy: 0.5878 - 146s/epoch - 94ms/step
# Epoch 12/100
# 1563/1563 - 147s - loss: 0.8433 - accuracy: 0.7169 - val_loss: 1.0986 - val_accuracy: 0.6176 - 147s/epoch - 94ms/step
# Epoch 13/100
# 1563/1563 - 147s - loss: 0.7873 - accuracy: 0.7355 - val_loss: 1.0797 - val_accuracy: 0.6357 - 147s/epoch - 94ms/step
# Epoch 14/100
# 1563/1563 - 148s - loss: 0.7382 - accuracy: 0.7559 - val_loss: 1.0300 - val_accuracy: 0.6563 - 148s/epoch - 94ms/step
# Epoch 15/100
# 1563/1563 - 148s - loss: 0.6862 - accuracy: 0.7729 - val_loss: 1.0487 - val_accuracy: 0.6551 - 148s/epoch - 95ms/step
# Epoch 16/100
# 1563/1563 - 149s - loss: 0.6332 - accuracy: 0.7903 - val_loss: 1.1690 - val_accuracy: 0.6316 - 149s/epoch - 95ms/step
# Epoch 17/100
# 1563/1563 - 150s - loss: 0.5957 - accuracy: 0.8030 - val_loss: 1.0271 - val_accuracy: 0.6754 - 150s/epoch - 96ms/step
# Epoch 18/100
# 1563/1563 - 148s - loss: 0.5511 - accuracy: 0.8229 - val_loss: 1.0783 - val_accuracy: 0.6572 - 148s/epoch - 95ms/step
# Epoch 19/100
# 1563/1563 - 151s - loss: 0.5165 - accuracy: 0.8345 - val_loss: 1.0198 - val_accuracy: 0.6763 - 151s/epoch - 96ms/step
# Epoch 20/100
# 1563/1563 - 150s - loss: 0.4758 - accuracy: 0.8457 - val_loss: 1.0929 - val_accuracy: 0.6671 - 150s/epoch - 96ms/step
# Epoch 21/100
# 1563/1563 - 152s - loss: 0.4488 - accuracy: 0.8562 - val_loss: 1.1801 - val_accuracy: 0.6549 - 152s/epoch - 97ms/step
# Epoch 22/100
# 1563/1563 - 148s - loss: 0.4200 - accuracy: 0.8666 - val_loss: 1.1416 - val_accuracy: 0.6570 - 148s/epoch - 95ms/step
# Epoch 23/100
# 1563/1563 - 147s - loss: 0.3887 - accuracy: 0.8778 - val_loss: 1.1700 - val_accuracy: 0.6577 - 147s/epoch - 94ms/step
# Epoch 24/100
# 1563/1563 - 147s - loss: 0.3598 - accuracy: 0.8852 - val_loss: 1.0706 - val_accuracy: 0.6784 - 147s/epoch - 94ms/step
# Epoch 25/100
# 1563/1563 - 146s - loss: 0.3375 - accuracy: 0.8941 - val_loss: 1.0655 - val_accuracy: 0.6888 - 146s/epoch - 94ms/step
# Epoch 26/100
# 1563/1563 - 146s - loss: 0.3200 - accuracy: 0.9011 - val_loss: 1.1445 - val_accuracy: 0.6759 - 146s/epoch - 93ms/step
# Epoch 27/100
# 1563/1563 - 147s - loss: 0.3006 - accuracy: 0.9063 - val_loss: 1.2186 - val_accuracy: 0.6825 - 147s/epoch - 94ms/step
# Epoch 28/100
# 1563/1563 - 147s - loss: 0.2778 - accuracy: 0.9142 - val_loss: 1.0651 - val_accuracy: 0.6990 - 147s/epoch - 94ms/step
# Epoch 29/100
# 1563/1563 - 149s - loss: 0.2491 - accuracy: 0.9223 - val_loss: 1.0731 - val_accuracy: 0.7025 - 149s/epoch - 95ms/step
# Epoch 30/100
# 1563/1563 - 148s - loss: 0.2376 - accuracy: 0.9269 - val_loss: 1.0916 - val_accuracy: 0.7018 - 148s/epoch - 95ms/step
# Epoch 31/100
# 1563/1563 - 147s - loss: 0.2315 - accuracy: 0.9301 - val_loss: 1.1967 - val_accuracy: 0.6869 - 147s/epoch - 94ms/step
# Epoch 32/100
# 1563/1563 - 146s - loss: 0.2105 - accuracy: 0.9370 - val_loss: 1.0999 - val_accuracy: 0.7052 - 146s/epoch - 93ms/step
# Epoch 33/100
# 1563/1563 - 146s - loss: 0.2032 - accuracy: 0.9410 - val_loss: 1.2001 - val_accuracy: 0.6841 - 146s/epoch - 93ms/step
# Epoch 34/100
# 1563/1563 - 146s - loss: 0.1855 - accuracy: 0.9450 - val_loss: 1.2178 - val_accuracy: 0.7005 - 146s/epoch - 93ms/step
# Epoch 35/100
# 1563/1563 - 146s - loss: 0.1845 - accuracy: 0.9446 - val_loss: 1.3534 - val_accuracy: 0.6670 - 146s/epoch - 94ms/step
# Epoch 36/100
# 1563/1563 - 146s - loss: 0.1760 - accuracy: 0.9483 - val_loss: 1.2136 - val_accuracy: 0.7025 - 146s/epoch - 93ms/step
# Epoch 37/100
# 1563/1563 - 146s - loss: 0.1563 - accuracy: 0.9534 - val_loss: 1.1342 - val_accuracy: 0.7103 - 146s/epoch - 93ms/step
# Epoch 38/100
# 1563/1563 - 146s - loss: 0.1502 - accuracy: 0.9570 - val_loss: 1.2551 - val_accuracy: 0.6914 - 146s/epoch - 94ms/step
# Epoch 39/100
# 1563/1563 - 146s - loss: 0.1382 - accuracy: 0.9597 - val_loss: 1.1630 - val_accuracy: 0.7165 - 146s/epoch - 93ms/step
# Epoch 40/100
# 1563/1563 - 146s - loss: 0.1335 - accuracy: 0.9611 - val_loss: 1.1834 - val_accuracy: 0.7139 - 146s/epoch - 93ms/step
# Epoch 41/100
# 1563/1563 - 146s - loss: 0.1222 - accuracy: 0.9639 - val_loss: 1.6541 - val_accuracy: 0.6484 - 146s/epoch - 93ms/step
# Epoch 42/100
# 1563/1563 - 146s - loss: 0.1218 - accuracy: 0.9646 - val_loss: 1.2161 - val_accuracy: 0.7038 - 146s/epoch - 93ms/step
# Epoch 43/100
# 1563/1563 - 146s - loss: 0.1139 - accuracy: 0.9670 - val_loss: 1.2448 - val_accuracy: 0.7052 - 146s/epoch - 93ms/step
# Epoch 44/100
# 1563/1563 - 146s - loss: 0.1083 - accuracy: 0.9691 - val_loss: 1.1911 - val_accuracy: 0.7182 - 146s/epoch - 93ms/step
# Epoch 45/100
# 1563/1563 - 146s - loss: 0.1037 - accuracy: 0.9704 - val_loss: 1.1349 - val_accuracy: 0.7212 - 146s/epoch - 94ms/step
# Epoch 46/100
# 1563/1563 - 146s - loss: 0.1043 - accuracy: 0.9703 - val_loss: 1.2141 - val_accuracy: 0.7134 - 146s/epoch - 93ms/step
# Epoch 47/100
# 1563/1563 - 146s - loss: 0.0971 - accuracy: 0.9721 - val_loss: 1.3928 - val_accuracy: 0.7001 - 146s/epoch - 94ms/step
# Epoch 48/100
# 1563/1563 - 146s - loss: 0.0956 - accuracy: 0.9730 - val_loss: 1.2401 - val_accuracy: 0.7171 - 146s/epoch - 93ms/step
# Epoch 49/100
# 1563/1563 - 146s - loss: 0.0983 - accuracy: 0.9715 - val_loss: 1.4080 - val_accuracy: 0.6942 - 146s/epoch - 93ms/step
# Epoch 50/100
# 1563/1563 - 146s - loss: 0.0843 - accuracy: 0.9754 - val_loss: 1.2844 - val_accuracy: 0.7230 - 146s/epoch - 93ms/step
# Epoch 51/100
# 1563/1563 - 146s - loss: 0.0836 - accuracy: 0.9762 - val_loss: 1.3052 - val_accuracy: 0.7135 - 146s/epoch - 94ms/step
# Epoch 52/100
# 1563/1563 - 146s - loss: 0.0785 - accuracy: 0.9782 - val_loss: 1.2083 - val_accuracy: 0.7282 - 146s/epoch - 93ms/step
# Epoch 53/100
# 1563/1563 - 146s - loss: 0.0775 - accuracy: 0.9788 - val_loss: 1.2948 - val_accuracy: 0.7191 - 146s/epoch - 93ms/step
# Epoch 54/100
# 1563/1563 - 146s - loss: 0.0707 - accuracy: 0.9797 - val_loss: 1.2894 - val_accuracy: 0.7187 - 146s/epoch - 93ms/step
# Epoch 55/100
# 1563/1563 - 146s - loss: 0.0738 - accuracy: 0.9789 - val_loss: 1.3514 - val_accuracy: 0.7190 - 146s/epoch - 93ms/step
# Epoch 56/100
# 1563/1563 - 146s - loss: 0.0725 - accuracy: 0.9796 - val_loss: 1.4056 - val_accuracy: 0.6934 - 146s/epoch - 94ms/step
# Epoch 57/100
# 1563/1563 - 146s - loss: 0.0785 - accuracy: 0.9782 - val_loss: 1.3266 - val_accuracy: 0.7088 - 146s/epoch - 93ms/step
# Epoch 58/100
# 1563/1563 - 146s - loss: 0.0677 - accuracy: 0.9813 - val_loss: 1.1950 - val_accuracy: 0.7270 - 146s/epoch - 93ms/step
# Epoch 59/100
# 1563/1563 - 146s - loss: 0.0678 - accuracy: 0.9810 - val_loss: 1.2392 - val_accuracy: 0.7348 - 146s/epoch - 93ms/step
# Epoch 60/100
# 1563/1563 - 146s - loss: 0.0658 - accuracy: 0.9818 - val_loss: 1.3263 - val_accuracy: 0.7095 - 146s/epoch - 93ms/step
# Epoch 61/100
# 1563/1563 - 146s - loss: 0.0546 - accuracy: 0.9845 - val_loss: 1.3156 - val_accuracy: 0.7248 - 146s/epoch - 93ms/step
# Epoch 62/100
# 1563/1563 - 146s - loss: 0.0572 - accuracy: 0.9837 - val_loss: 1.3010 - val_accuracy: 0.7257 - 146s/epoch - 93ms/step
# Epoch 63/100
# 1563/1563 - 146s - loss: 0.0607 - accuracy: 0.9831 - val_loss: 1.2244 - val_accuracy: 0.7294 - 146s/epoch - 94ms/step
# Epoch 64/100
# 1563/1563 - 146s - loss: 0.0523 - accuracy: 0.9854 - val_loss: 1.4395 - val_accuracy: 0.7007 - 146s/epoch - 93ms/step
# Epoch 65/100
# 1563/1563 - 146s - loss: 0.0599 - accuracy: 0.9839 - val_loss: 1.2657 - val_accuracy: 0.7280 - 146s/epoch - 93ms/step
# Epoch 66/100
# 1563/1563 - 146s - loss: 0.0484 - accuracy: 0.9862 - val_loss: 1.2905 - val_accuracy: 0.7289 - 146s/epoch - 93ms/step
# Epoch 67/100
# 1563/1563 - 146s - loss: 0.0514 - accuracy: 0.9857 - val_loss: 1.2998 - val_accuracy: 0.7348 - 146s/epoch - 94ms/step
# Epoch 68/100
# 1563/1563 - 146s - loss: 0.0392 - accuracy: 0.9890 - val_loss: 1.4877 - val_accuracy: 0.7050 - 146s/epoch - 93ms/step
# Epoch 69/100
# 1563/1563 - 146s - loss: 0.0482 - accuracy: 0.9866 - val_loss: 1.3961 - val_accuracy: 0.7171 - 146s/epoch - 94ms/step
# Epoch 70/100
# 1563/1563 - 146s - loss: 0.0454 - accuracy: 0.9879 - val_loss: 1.4133 - val_accuracy: 0.7293 - 146s/epoch - 93ms/step
# Epoch 71/100
# 1563/1563 - 146s - loss: 0.0431 - accuracy: 0.9881 - val_loss: 1.3210 - val_accuracy: 0.7222 - 146s/epoch - 94ms/step
# Epoch 72/100
# 1563/1563 - 146s - loss: 0.0417 - accuracy: 0.9890 - val_loss: 1.3652 - val_accuracy: 0.7318 - 146s/epoch - 94ms/step
# Epoch 73/100
# 1563/1563 - 146s - loss: 0.0451 - accuracy: 0.9878 - val_loss: 1.3156 - val_accuracy: 0.7320 - 146s/epoch - 94ms/step
# Epoch 74/100
# 1563/1563 - 146s - loss: 0.0461 - accuracy: 0.9878 - val_loss: 1.2940 - val_accuracy: 0.7353 - 146s/epoch - 93ms/step
# Epoch 75/100
# 1563/1563 - 146s - loss: 0.0407 - accuracy: 0.9887 - val_loss: 1.4789 - val_accuracy: 0.7100 - 146s/epoch - 93ms/step
# Epoch 76/100
# 1563/1563 - 146s - loss: 0.0396 - accuracy: 0.9887 - val_loss: 1.3070 - val_accuracy: 0.7376 - 146s/epoch - 93ms/step
# Epoch 77/100
# 1563/1563 - 146s - loss: 0.0400 - accuracy: 0.9887 - val_loss: 1.4766 - val_accuracy: 0.7231 - 146s/epoch - 93ms/step
# Epoch 78/100
# 1563/1563 - 146s - loss: 0.0439 - accuracy: 0.9885 - val_loss: 1.4447 - val_accuracy: 0.7107 - 146s/epoch - 94ms/step
# Epoch 79/100
# 1563/1563 - 146s - loss: 0.0445 - accuracy: 0.9880 - val_loss: 1.2640 - val_accuracy: 0.7431 - 146s/epoch - 94ms/step
# Epoch 80/100
# 1563/1563 - 146s - loss: 0.0356 - accuracy: 0.9902 - val_loss: 1.3397 - val_accuracy: 0.7350 - 146s/epoch - 94ms/step
# Epoch 81/100
# 1563/1563 - 146s - loss: 0.0379 - accuracy: 0.9897 - val_loss: 1.3737 - val_accuracy: 0.7336 - 146s/epoch - 93ms/step
# Epoch 82/100
# 1563/1563 - 146s - loss: 0.0385 - accuracy: 0.9891 - val_loss: 1.4173 - val_accuracy: 0.7301 - 146s/epoch - 94ms/step
# Epoch 83/100
# 1563/1563 - 146s - loss: 0.0355 - accuracy: 0.9901 - val_loss: 1.4169 - val_accuracy: 0.7277 - 146s/epoch - 93ms/step
# Epoch 84/100
# 1563/1563 - 146s - loss: 0.0377 - accuracy: 0.9900 - val_loss: 1.3733 - val_accuracy: 0.7298 - 146s/epoch - 93ms/step
# Epoch 85/100
# 1563/1563 - 146s - loss: 0.0374 - accuracy: 0.9897 - val_loss: 1.5346 - val_accuracy: 0.7206 - 146s/epoch - 93ms/step
# Epoch 86/100
# 1563/1563 - 146s - loss: 0.0348 - accuracy: 0.9902 - val_loss: 1.3393 - val_accuracy: 0.7358 - 146s/epoch - 93ms/step
# Epoch 87/100
# 1563/1563 - 146s - loss: 0.0379 - accuracy: 0.9893 - val_loss: 1.2908 - val_accuracy: 0.7413 - 146s/epoch - 94ms/step
# Epoch 88/100
# 1563/1563 - 146s - loss: 0.0257 - accuracy: 0.9926 - val_loss: 1.4881 - val_accuracy: 0.7331 - 146s/epoch - 94ms/step
# Epoch 89/100
# 1563/1563 - 146s - loss: 0.0316 - accuracy: 0.9911 - val_loss: 1.5791 - val_accuracy: 0.7081 - 146s/epoch - 93ms/step
# Epoch 90/100
# 1563/1563 - 146s - loss: 0.0407 - accuracy: 0.9886 - val_loss: 1.3313 - val_accuracy: 0.7269 - 146s/epoch - 94ms/step
# Epoch 91/100
# 1563/1563 - 146s - loss: 0.0347 - accuracy: 0.9908 - val_loss: 1.4325 - val_accuracy: 0.7170 - 146s/epoch - 94ms/step
# Epoch 92/100
# 1563/1563 - 146s - loss: 0.0290 - accuracy: 0.9925 - val_loss: 1.3907 - val_accuracy: 0.7293 - 146s/epoch - 94ms/step
# Epoch 93/100
# 1563/1563 - 146s - loss: 0.0294 - accuracy: 0.9919 - val_loss: 1.3839 - val_accuracy: 0.7281 - 146s/epoch - 94ms/step
# Epoch 94/100
# 1563/1563 - 146s - loss: 0.0360 - accuracy: 0.9901 - val_loss: 1.3767 - val_accuracy: 0.7338 - 146s/epoch - 94ms/step
# Epoch 95/100
# 1563/1563 - 146s - loss: 0.0301 - accuracy: 0.9910 - val_loss: 1.5680 - val_accuracy: 0.7029 - 146s/epoch - 94ms/step
# Epoch 96/100
# 1563/1563 - 146s - loss: 0.0265 - accuracy: 0.9927 - val_loss: 1.4165 - val_accuracy: 0.7431 - 146s/epoch - 94ms/step
# Epoch 97/100
# 1563/1563 - 146s - loss: 0.0252 - accuracy: 0.9934 - val_loss: 1.4835 - val_accuracy: 0.7432 - 146s/epoch - 94ms/step
# Epoch 98/100
# 1563/1563 - 146s - loss: 0.0338 - accuracy: 0.9905 - val_loss: 1.3975 - val_accuracy: 0.7406 - 146s/epoch - 94ms/step
# Epoch 99/100
# 1563/1563 - 146s - loss: 0.0365 - accuracy: 0.9906 - val_loss: 1.3011 - val_accuracy: 0.7384 - 146s/epoch - 94ms/step
# Epoch 100/100
# 1563/1563 - 146s - loss: 0.0276 - accuracy: 0.9922 - val_loss: 1.3847 - val_accuracy: 0.7335 - 146s/epoch - 93ms/step

# %%
 # evaluate model
_, acc = model.evaluate(testX, testY, verbose=verb)
print('Acurácia: %.3f' % (acc * 100.0))
# Out:
# 313/313 - 7s - loss: 1.3847 - accuracy: 0.7335 - 7s/epoch - 22ms/step
# Acurácia: 73.350

# %%
 # learning curves
summarize_diagnostics(history)

# %%
model_name = f'cifar-resnet50-baseline-holdout-{epochs}epochs_dropout.npy'
model.save(model_name)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 55). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: cifar-resnet50-baseline-holdout-100epochs_dropout.npy\assets
# INFO:tensorflow:Assets written to: cifar-resnet50-baseline-holdout-100epochs_dropout.npy\assets

# %%
# entry point, run the test harness
#run_test_harness(epochs=100, verb=1)
