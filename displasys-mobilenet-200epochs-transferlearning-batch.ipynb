# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
import time
import numpy as np

# %%
# baseline model with dropout and data augmentation on the cifar10 dataset
import sys
from matplotlib import pyplot
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dropout
from keras.layers import BatchNormalization

# %%
# load train and test dataset
def load_dataset():
    # load dataset
    data_x = np.load('data_x_original.npy')
    data_y = np.load('data_y_original.npy')
    #percentage of the dataset which will be on TRAIN - TEST - VALIDATION
    TOTAL_IMAGES = len(data_y)
    print("TOTAL_IMAGES = ", TOTAL_IMAGES)
    
    TRAIN_PERCENTAGE = 0.8
    TEST_PERCENTAGE = 0.1
    VALIDATION_PERCENTAGE = 0.1

    train_size = int(TRAIN_PERCENTAGE * TOTAL_IMAGES)
    test_size = int(TEST_PERCENTAGE * TOTAL_IMAGES)
    validation_size = int(VALIDATION_PERCENTAGE * TOTAL_IMAGES)

    train_x = data_x[:train_size] #taking train images from original data
    train_y = data_y[:train_size]
    data_x = data_x[train_size:] #removing train images from original data
    data_y = data_y[train_size:]

    test_x = data_x[:test_size] #taking test images from original data
    test_y = data_y[:test_size]
    data_x = data_x[test_size:] #removing test images from original data
    data_y = data_y[test_size:]

    validation_x = data_x #all the remainder images we can put on validation
    validation_y = data_y

    del data_x #free some unused memory
    del data_y

    print("train_size = ", len(train_y))
    print("test_size = ", len(test_y))
    print("validation_size = ", len(validation_y))
 # one hot encode target values
    train_y = to_categorical(train_y)
    test_y = to_categorical(test_y)
    validation_y = to_categorical(validation_y)
    return train_x, train_y, test_x, test_y, validation_x, validation_y

# %%
# scale pixels
def prep_pixels(train, test, validation):
 # convert from integers to floats
 train_norm = train.astype('float32')
 test_norm = test.astype('float32')
 validation_norm = validation.astype('float32')
 # normalize to range 0-1
 train_norm = train_norm / 255.0
 test_norm = test_norm / 255.0
 validation_norm = validation_norm / 255.0
 # return normalized images
 return train_norm, test_norm, validation_norm

# %%
# define cnn model
def define_model():
    new_model = Sequential()
    
    model = tf.keras.applications.MobileNet(
        include_top=False,
        weights="imagenet",
        input_tensor=None,
        input_shape=(128,128,3),
        pooling=None,
        classes=4,
       # classifier_activation="softmax",
    #    **kwargs
        )
    
    new_model.add(model)
    #3rd conv layer
    new_model.add(tf.keras.layers.Conv2D(32, 3, padding="same"))
    new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.MaxPooling2D(2))
    #new_model.add(tf.keras.layers.Dropout(0.2))
    #4th conv layer
    new_model.add(tf.keras.layers.Conv2D(64, 3, padding="same"))
    new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.MaxPooling2D(2))
    #new_model.add(tf.keras.layers.Dropout(0.2))
    #Flatten Layer
    new_model.add(tf.keras.layers.Flatten())

    new_model.add(tf.keras.layers.Dense(128))
    new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.Dropout(0.2))
    #output Dense Layer
    new_model.add(tf.keras.layers.Dense(4))
    new_model.add(tf.keras.layers.Activation('softmax'))
    adam = tf.keras.optimizers.Adam(lr=0.001)
    new_model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])
    return new_model

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
 # plot loss
    model_trained = history
    accuracy = model_trained.history['accuracy']
    val_accuracy = model_trained.history['val_accuracy']
    loss = model_trained.history['loss']
    val_loss = model_trained.history['val_loss']
    epochs = range(len(accuracy))
    plt.plot(epochs, accuracy, 'b', label='Acurácia de treino')
    plt.plot(epochs, val_accuracy, 'g', label='Acurácia de validação')
    plt.title('Acurácia de treino e validação')
    plt.legend()
    plt.figure()
    plt.plot(epochs, loss, 'b', label='Perda no treino')
    plt.plot(epochs, val_loss, 'g', label='Perda na validação')
    plt.title('Perda na validação e treino')
    plt.legend()
    plt.show()

# %%
epochs = 200
verb = 2

# %%
trainX, trainY, testX, testY, validationX, validationY = load_dataset()
 # prepare pixel data
trainX, testX, validationX = prep_pixels(trainX, testX, validationX)
 # define model
model = define_model()
# Out:
# TOTAL_IMAGES =  592
# train_size =  473
# test_size =  59
# validation_size =  60
# C:\Users\tmcle\.conda\envs\tf\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
#validationX[0]
trainY[0]
# Out:
# array([0., 0., 1., 0.], dtype=float32)

# %%
history = model.fit(trainX, trainY, epochs=epochs, validation_data=(testX, testY), verbose=verb, shuffle="false")
# Out:
# Epoch 1/200
# 15/15 - 33s - loss: 1.2538 - accuracy: 0.4545 - val_loss: 3.1566 - val_accuracy: 0.2712 - 33s/epoch - 2s/step
# Epoch 2/200
# 15/15 - 2s - loss: 0.6128 - accuracy: 0.7590 - val_loss: 3.2028 - val_accuracy: 0.2712 - 2s/epoch - 107ms/step
# Epoch 3/200
# 15/15 - 2s - loss: 0.2647 - accuracy: 0.9260 - val_loss: 3.7759 - val_accuracy: 0.2712 - 2s/epoch - 107ms/step
# Epoch 4/200
# 15/15 - 2s - loss: 0.1223 - accuracy: 0.9746 - val_loss: 3.7556 - val_accuracy: 0.2712 - 2s/epoch - 107ms/step
# Epoch 5/200
# 15/15 - 2s - loss: 0.0515 - accuracy: 0.9937 - val_loss: 3.6038 - val_accuracy: 0.3051 - 2s/epoch - 107ms/step
# Epoch 6/200
# 15/15 - 2s - loss: 0.0271 - accuracy: 0.9937 - val_loss: 3.0480 - val_accuracy: 0.3559 - 2s/epoch - 106ms/step
# Epoch 7/200
# 15/15 - 2s - loss: 0.0149 - accuracy: 1.0000 - val_loss: 2.3849 - val_accuracy: 0.3898 - 2s/epoch - 107ms/step
# Epoch 8/200
# 15/15 - 2s - loss: 0.0130 - accuracy: 1.0000 - val_loss: 2.2116 - val_accuracy: 0.4576 - 2s/epoch - 107ms/step
# Epoch 9/200
# 15/15 - 2s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 2.1371 - val_accuracy: 0.4407 - 2s/epoch - 106ms/step
# Epoch 10/200
# 15/15 - 2s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 2.1120 - val_accuracy: 0.4746 - 2s/epoch - 107ms/step
# Epoch 11/200
# 15/15 - 2s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 2.1379 - val_accuracy: 0.4746 - 2s/epoch - 107ms/step
# Epoch 12/200
# 15/15 - 2s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 2.1648 - val_accuracy: 0.5085 - 2s/epoch - 109ms/step
# Epoch 13/200
# 15/15 - 2s - loss: 0.0048 - accuracy: 1.0000 - val_loss: 1.9726 - val_accuracy: 0.5593 - 2s/epoch - 109ms/step
# Epoch 14/200
# 15/15 - 2s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.6831 - val_accuracy: 0.5424 - 2s/epoch - 107ms/step
# Epoch 15/200
# 15/15 - 2s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.4225 - val_accuracy: 0.6271 - 2s/epoch - 107ms/step
# Epoch 16/200
# 15/15 - 2s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.2301 - val_accuracy: 0.6949 - 2s/epoch - 108ms/step
# Epoch 17/200
# 15/15 - 2s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 1.1179 - val_accuracy: 0.6949 - 2s/epoch - 107ms/step
# Epoch 18/200
# 15/15 - 2s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.9973 - val_accuracy: 0.7288 - 2s/epoch - 107ms/step
# Epoch 19/200
# 15/15 - 2s - loss: 0.0094 - accuracy: 0.9979 - val_loss: 0.9334 - val_accuracy: 0.6949 - 2s/epoch - 108ms/step
# Epoch 20/200
# 15/15 - 2s - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.9089 - val_accuracy: 0.7458 - 2s/epoch - 107ms/step
# Epoch 21/200
# 15/15 - 2s - loss: 0.0162 - accuracy: 0.9958 - val_loss: 0.7414 - val_accuracy: 0.7458 - 2s/epoch - 108ms/step
# Epoch 22/200
# 15/15 - 2s - loss: 0.0264 - accuracy: 0.9937 - val_loss: 2.1729 - val_accuracy: 0.4746 - 2s/epoch - 107ms/step
# Epoch 23/200
# 15/15 - 2s - loss: 0.0944 - accuracy: 0.9683 - val_loss: 2.1053 - val_accuracy: 0.6441 - 2s/epoch - 111ms/step
# Epoch 24/200
# 15/15 - 2s - loss: 0.2677 - accuracy: 0.9239 - val_loss: 1.6488 - val_accuracy: 0.5763 - 2s/epoch - 108ms/step
# Epoch 25/200
# 15/15 - 2s - loss: 0.3974 - accuracy: 0.8647 - val_loss: 2.4496 - val_accuracy: 0.5593 - 2s/epoch - 109ms/step
# Epoch 26/200
# 15/15 - 2s - loss: 0.2738 - accuracy: 0.8964 - val_loss: 1.8891 - val_accuracy: 0.6780 - 2s/epoch - 108ms/step
# Epoch 27/200
# 15/15 - 2s - loss: 0.1699 - accuracy: 0.9408 - val_loss: 1.8386 - val_accuracy: 0.6441 - 2s/epoch - 109ms/step
# Epoch 28/200
# 15/15 - 2s - loss: 0.0746 - accuracy: 0.9831 - val_loss: 1.9563 - val_accuracy: 0.6949 - 2s/epoch - 107ms/step
# Epoch 29/200
# 15/15 - 2s - loss: 0.0593 - accuracy: 0.9810 - val_loss: 1.2424 - val_accuracy: 0.7119 - 2s/epoch - 108ms/step
# Epoch 30/200
# 15/15 - 2s - loss: 0.0682 - accuracy: 0.9746 - val_loss: 1.4839 - val_accuracy: 0.6780 - 2s/epoch - 107ms/step
# Epoch 31/200
# 15/15 - 2s - loss: 0.1289 - accuracy: 0.9598 - val_loss: 2.7445 - val_accuracy: 0.5593 - 2s/epoch - 108ms/step
# Epoch 32/200
# 15/15 - 2s - loss: 0.0730 - accuracy: 0.9746 - val_loss: 2.2284 - val_accuracy: 0.6102 - 2s/epoch - 110ms/step
# Epoch 33/200
# 15/15 - 2s - loss: 0.0321 - accuracy: 0.9873 - val_loss: 1.6568 - val_accuracy: 0.7458 - 2s/epoch - 108ms/step
# Epoch 34/200
# 15/15 - 2s - loss: 0.0211 - accuracy: 0.9937 - val_loss: 1.6382 - val_accuracy: 0.6949 - 2s/epoch - 106ms/step
# Epoch 35/200
# 15/15 - 2s - loss: 0.0219 - accuracy: 0.9958 - val_loss: 1.1176 - val_accuracy: 0.7627 - 2s/epoch - 107ms/step
# Epoch 36/200
# 15/15 - 2s - loss: 0.0329 - accuracy: 0.9937 - val_loss: 1.1401 - val_accuracy: 0.7458 - 2s/epoch - 108ms/step
# Epoch 37/200
# 15/15 - 2s - loss: 0.0202 - accuracy: 0.9958 - val_loss: 1.0380 - val_accuracy: 0.7288 - 2s/epoch - 107ms/step
# Epoch 38/200
# 15/15 - 2s - loss: 0.0193 - accuracy: 0.9915 - val_loss: 0.8801 - val_accuracy: 0.7627 - 2s/epoch - 107ms/step
# Epoch 39/200
# 15/15 - 2s - loss: 0.0489 - accuracy: 0.9852 - val_loss: 1.4411 - val_accuracy: 0.7119 - 2s/epoch - 107ms/step
# Epoch 40/200
# 15/15 - 2s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 1.5564 - val_accuracy: 0.6610 - 2s/epoch - 107ms/step
# Epoch 41/200
# 15/15 - 2s - loss: 0.0165 - accuracy: 0.9958 - val_loss: 1.7581 - val_accuracy: 0.5932 - 2s/epoch - 108ms/step
# Epoch 42/200
# 15/15 - 2s - loss: 0.0131 - accuracy: 1.0000 - val_loss: 1.0566 - val_accuracy: 0.6610 - 2s/epoch - 106ms/step
# Epoch 43/200
# 15/15 - 2s - loss: 0.0139 - accuracy: 0.9958 - val_loss: 1.5661 - val_accuracy: 0.6610 - 2s/epoch - 107ms/step
# Epoch 44/200
# 15/15 - 2s - loss: 0.0076 - accuracy: 1.0000 - val_loss: 1.1377 - val_accuracy: 0.7119 - 2s/epoch - 107ms/step
# Epoch 45/200
# 15/15 - 2s - loss: 0.0079 - accuracy: 0.9958 - val_loss: 0.7202 - val_accuracy: 0.8305 - 2s/epoch - 107ms/step
# Epoch 46/200
# 15/15 - 2s - loss: 0.0039 - accuracy: 0.9979 - val_loss: 0.7347 - val_accuracy: 0.8136 - 2s/epoch - 107ms/step
# Epoch 47/200
# 15/15 - 2s - loss: 0.0288 - accuracy: 0.9937 - val_loss: 1.0526 - val_accuracy: 0.7797 - 2s/epoch - 107ms/step
# Epoch 48/200
# 15/15 - 2s - loss: 0.0079 - accuracy: 0.9979 - val_loss: 1.0444 - val_accuracy: 0.7627 - 2s/epoch - 107ms/step
# Epoch 49/200
# 15/15 - 2s - loss: 0.0376 - accuracy: 0.9894 - val_loss: 1.1931 - val_accuracy: 0.7288 - 2s/epoch - 107ms/step
# Epoch 50/200
# 15/15 - 2s - loss: 0.0253 - accuracy: 0.9937 - val_loss: 1.0975 - val_accuracy: 0.7627 - 2s/epoch - 107ms/step
# Epoch 51/200
# 15/15 - 2s - loss: 0.0870 - accuracy: 0.9767 - val_loss: 2.0550 - val_accuracy: 0.6441 - 2s/epoch - 107ms/step
# Epoch 52/200
# 15/15 - 2s - loss: 0.0671 - accuracy: 0.9767 - val_loss: 1.3406 - val_accuracy: 0.6780 - 2s/epoch - 107ms/step
# Epoch 53/200
# 15/15 - 2s - loss: 0.0749 - accuracy: 0.9810 - val_loss: 2.2934 - val_accuracy: 0.6102 - 2s/epoch - 107ms/step
# Epoch 54/200
# 15/15 - 2s - loss: 0.1139 - accuracy: 0.9641 - val_loss: 2.3234 - val_accuracy: 0.5763 - 2s/epoch - 107ms/step
# Epoch 55/200
# 15/15 - 2s - loss: 0.0849 - accuracy: 0.9767 - val_loss: 1.9162 - val_accuracy: 0.6610 - 2s/epoch - 108ms/step
# Epoch 56/200
# 15/15 - 2s - loss: 0.0638 - accuracy: 0.9725 - val_loss: 1.9153 - val_accuracy: 0.6610 - 2s/epoch - 111ms/step
# Epoch 57/200
# 15/15 - 2s - loss: 0.0255 - accuracy: 0.9915 - val_loss: 2.5626 - val_accuracy: 0.5763 - 2s/epoch - 109ms/step
# Epoch 58/200
# 15/15 - 2s - loss: 0.0867 - accuracy: 0.9725 - val_loss: 1.0829 - val_accuracy: 0.6949 - 2s/epoch - 107ms/step
# Epoch 59/200
# 15/15 - 2s - loss: 0.0737 - accuracy: 0.9852 - val_loss: 1.5781 - val_accuracy: 0.6610 - 2s/epoch - 108ms/step
# Epoch 60/200
# 15/15 - 2s - loss: 0.0329 - accuracy: 0.9873 - val_loss: 1.1836 - val_accuracy: 0.7288 - 2s/epoch - 108ms/step
# Epoch 61/200
# 15/15 - 2s - loss: 0.0434 - accuracy: 0.9831 - val_loss: 0.8511 - val_accuracy: 0.7966 - 2s/epoch - 110ms/step
# Epoch 62/200
# 15/15 - 2s - loss: 0.0813 - accuracy: 0.9810 - val_loss: 1.1908 - val_accuracy: 0.6780 - 2s/epoch - 107ms/step
# Epoch 63/200
# 15/15 - 2s - loss: 0.0359 - accuracy: 0.9873 - val_loss: 1.3446 - val_accuracy: 0.7288 - 2s/epoch - 111ms/step
# Epoch 64/200
# 15/15 - 2s - loss: 0.0146 - accuracy: 0.9958 - val_loss: 0.9590 - val_accuracy: 0.8136 - 2s/epoch - 111ms/step
# Epoch 65/200
# 15/15 - 2s - loss: 0.0101 - accuracy: 0.9979 - val_loss: 0.6852 - val_accuracy: 0.8305 - 2s/epoch - 107ms/step
# Epoch 66/200
# 15/15 - 2s - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.6164 - val_accuracy: 0.8136 - 2s/epoch - 109ms/step
# Epoch 67/200
# 15/15 - 2s - loss: 0.0241 - accuracy: 0.9937 - val_loss: 0.6348 - val_accuracy: 0.7966 - 2s/epoch - 109ms/step
# Epoch 68/200
# 15/15 - 2s - loss: 0.0133 - accuracy: 0.9937 - val_loss: 0.7704 - val_accuracy: 0.7797 - 2s/epoch - 109ms/step
# Epoch 69/200
# 15/15 - 2s - loss: 0.0306 - accuracy: 0.9937 - val_loss: 0.7764 - val_accuracy: 0.8136 - 2s/epoch - 111ms/step
# Epoch 70/200
# 15/15 - 2s - loss: 0.0120 - accuracy: 0.9958 - val_loss: 0.6561 - val_accuracy: 0.7966 - 2s/epoch - 108ms/step
# Epoch 71/200
# 15/15 - 2s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.7335 - val_accuracy: 0.8136 - 2s/epoch - 108ms/step
# Epoch 72/200
# 15/15 - 2s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.6881 - val_accuracy: 0.8136 - 2s/epoch - 107ms/step
# Epoch 73/200
# 15/15 - 2s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6203 - val_accuracy: 0.8136 - 2s/epoch - 108ms/step
# Epoch 74/200
# 15/15 - 2s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5861 - val_accuracy: 0.8305 - 2s/epoch - 107ms/step
# Epoch 75/200
# 15/15 - 2s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.5599 - val_accuracy: 0.7966 - 2s/epoch - 109ms/step
# Epoch 76/200
# 15/15 - 2s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5515 - val_accuracy: 0.7966 - 2s/epoch - 109ms/step
# Epoch 77/200
# 15/15 - 2s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5440 - val_accuracy: 0.8136 - 2s/epoch - 108ms/step
# Epoch 78/200
# 15/15 - 2s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.6239 - val_accuracy: 0.8136 - 2s/epoch - 108ms/step
# Epoch 79/200
# 15/15 - 2s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5580 - val_accuracy: 0.8305 - 2s/epoch - 107ms/step
# Epoch 80/200
# 15/15 - 2s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5098 - val_accuracy: 0.8305 - 2s/epoch - 109ms/step
# Epoch 81/200
# 15/15 - 2s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5112 - val_accuracy: 0.8305 - 2s/epoch - 109ms/step
# Epoch 82/200
# 15/15 - 2s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.5207 - val_accuracy: 0.8305 - 2s/epoch - 109ms/step
# Epoch 83/200
# 15/15 - 2s - loss: 7.3888e-04 - accuracy: 1.0000 - val_loss: 0.5317 - val_accuracy: 0.8305 - 2s/epoch - 108ms/step
# Epoch 84/200
# 15/15 - 2s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5371 - val_accuracy: 0.8136 - 2s/epoch - 108ms/step
# Epoch 85/200
# 15/15 - 2s - loss: 8.4235e-04 - accuracy: 1.0000 - val_loss: 0.5482 - val_accuracy: 0.8136 - 2s/epoch - 109ms/step
# Epoch 86/200
# 15/15 - 2s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5474 - val_accuracy: 0.8136 - 2s/epoch - 109ms/step
# Epoch 87/200
# 15/15 - 2s - loss: 5.6621e-04 - accuracy: 1.0000 - val_loss: 0.5452 - val_accuracy: 0.8305 - 2s/epoch - 108ms/step
# Epoch 88/200
# 15/15 - 2s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5132 - val_accuracy: 0.8136 - 2s/epoch - 108ms/step
# Epoch 89/200
# 15/15 - 2s - loss: 0.0275 - accuracy: 0.9915 - val_loss: 0.5551 - val_accuracy: 0.8136 - 2s/epoch - 108ms/step
# Epoch 90/200
# 15/15 - 2s - loss: 0.0135 - accuracy: 0.9958 - val_loss: 1.2184 - val_accuracy: 0.7458 - 2s/epoch - 108ms/step
# Epoch 91/200
# 15/15 - 2s - loss: 0.0104 - accuracy: 0.9958 - val_loss: 1.4495 - val_accuracy: 0.7458 - 2s/epoch - 107ms/step
# Epoch 92/200
# 15/15 - 2s - loss: 0.0135 - accuracy: 0.9979 - val_loss: 1.0102 - val_accuracy: 0.7627 - 2s/epoch - 108ms/step
# Epoch 93/200
# 15/15 - 2s - loss: 0.0091 - accuracy: 0.9958 - val_loss: 0.8533 - val_accuracy: 0.7627 - 2s/epoch - 108ms/step
# Epoch 94/200
# 15/15 - 2s - loss: 0.0104 - accuracy: 0.9958 - val_loss: 0.8792 - val_accuracy: 0.7627 - 2s/epoch - 107ms/step
# Epoch 95/200
# 15/15 - 2s - loss: 0.0124 - accuracy: 0.9937 - val_loss: 1.1485 - val_accuracy: 0.7288 - 2s/epoch - 108ms/step
# Epoch 96/200
# 15/15 - 2s - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.8536 - val_accuracy: 0.7627 - 2s/epoch - 107ms/step
# Epoch 97/200
# 15/15 - 2s - loss: 0.0152 - accuracy: 0.9958 - val_loss: 2.7232 - val_accuracy: 0.5085 - 2s/epoch - 107ms/step
# Epoch 98/200
# 15/15 - 2s - loss: 0.0235 - accuracy: 0.9937 - val_loss: 1.7642 - val_accuracy: 0.6271 - 2s/epoch - 108ms/step
# Epoch 99/200
# 15/15 - 2s - loss: 0.0151 - accuracy: 0.9958 - val_loss: 1.2730 - val_accuracy: 0.7627 - 2s/epoch - 110ms/step
# Epoch 100/200
# 15/15 - 2s - loss: 0.0424 - accuracy: 0.9873 - val_loss: 1.1597 - val_accuracy: 0.7288 - 2s/epoch - 108ms/step
# Epoch 101/200
# 15/15 - 2s - loss: 0.0434 - accuracy: 0.9894 - val_loss: 2.1867 - val_accuracy: 0.5593 - 2s/epoch - 111ms/step
# Epoch 102/200
# 15/15 - 2s - loss: 0.0672 - accuracy: 0.9810 - val_loss: 2.5859 - val_accuracy: 0.5593 - 2s/epoch - 111ms/step
# Epoch 103/200
# 15/15 - 2s - loss: 0.0638 - accuracy: 0.9873 - val_loss: 3.0083 - val_accuracy: 0.4407 - 2s/epoch - 110ms/step
# Epoch 104/200
# 15/15 - 2s - loss: 0.1025 - accuracy: 0.9725 - val_loss: 1.2095 - val_accuracy: 0.7288 - 2s/epoch - 110ms/step
# Epoch 105/200
# 15/15 - 2s - loss: 0.0486 - accuracy: 0.9852 - val_loss: 1.1932 - val_accuracy: 0.6949 - 2s/epoch - 111ms/step
# Epoch 106/200
# 15/15 - 2s - loss: 0.0728 - accuracy: 0.9831 - val_loss: 1.5012 - val_accuracy: 0.6780 - 2s/epoch - 109ms/step
# Epoch 107/200
# 15/15 - 2s - loss: 0.0739 - accuracy: 0.9810 - val_loss: 1.6117 - val_accuracy: 0.6441 - 2s/epoch - 109ms/step
# Epoch 108/200
# 15/15 - 2s - loss: 0.0314 - accuracy: 0.9958 - val_loss: 2.1696 - val_accuracy: 0.6271 - 2s/epoch - 107ms/step
# Epoch 109/200
# 15/15 - 2s - loss: 0.0195 - accuracy: 0.9937 - val_loss: 1.1488 - val_accuracy: 0.7797 - 2s/epoch - 108ms/step
# Epoch 110/200
# 15/15 - 2s - loss: 0.0159 - accuracy: 0.9979 - val_loss: 1.2020 - val_accuracy: 0.7797 - 2s/epoch - 107ms/step
# Epoch 111/200
# 15/15 - 2s - loss: 0.0253 - accuracy: 0.9937 - val_loss: 1.1609 - val_accuracy: 0.7119 - 2s/epoch - 107ms/step
# Epoch 112/200
# 15/15 - 2s - loss: 0.0763 - accuracy: 0.9641 - val_loss: 2.3366 - val_accuracy: 0.5932 - 2s/epoch - 109ms/step
# Epoch 113/200
# 15/15 - 2s - loss: 0.0781 - accuracy: 0.9725 - val_loss: 1.7305 - val_accuracy: 0.7119 - 2s/epoch - 108ms/step
# Epoch 114/200
# 15/15 - 2s - loss: 0.0461 - accuracy: 0.9852 - val_loss: 1.1984 - val_accuracy: 0.7966 - 2s/epoch - 107ms/step
# Epoch 115/200
# 15/15 - 2s - loss: 0.0431 - accuracy: 0.9789 - val_loss: 2.4856 - val_accuracy: 0.5763 - 2s/epoch - 107ms/step
# Epoch 116/200
# 15/15 - 2s - loss: 0.0635 - accuracy: 0.9810 - val_loss: 0.6558 - val_accuracy: 0.8305 - 2s/epoch - 108ms/step
# Epoch 117/200
# 15/15 - 2s - loss: 0.0777 - accuracy: 0.9704 - val_loss: 0.6641 - val_accuracy: 0.8475 - 2s/epoch - 107ms/step
# Epoch 118/200
# 15/15 - 2s - loss: 0.0671 - accuracy: 0.9789 - val_loss: 1.6108 - val_accuracy: 0.7119 - 2s/epoch - 108ms/step
# Epoch 119/200
# 15/15 - 2s - loss: 0.0539 - accuracy: 0.9831 - val_loss: 2.7653 - val_accuracy: 0.5254 - 2s/epoch - 107ms/step
# Epoch 120/200
# 15/15 - 2s - loss: 0.0268 - accuracy: 0.9915 - val_loss: 2.0677 - val_accuracy: 0.6780 - 2s/epoch - 108ms/step
# Epoch 121/200
# 15/15 - 2s - loss: 0.0122 - accuracy: 0.9979 - val_loss: 2.2729 - val_accuracy: 0.7288 - 2s/epoch - 108ms/step
# Epoch 122/200
# 15/15 - 2s - loss: 0.0089 - accuracy: 0.9979 - val_loss: 1.5151 - val_accuracy: 0.7797 - 2s/epoch - 106ms/step
# Epoch 123/200
# 15/15 - 2s - loss: 0.0235 - accuracy: 0.9937 - val_loss: 0.7643 - val_accuracy: 0.7966 - 2s/epoch - 108ms/step
# Epoch 124/200
# 15/15 - 2s - loss: 0.0068 - accuracy: 0.9979 - val_loss: 1.9340 - val_accuracy: 0.6441 - 2s/epoch - 107ms/step
# Epoch 125/200
# 15/15 - 2s - loss: 0.0090 - accuracy: 1.0000 - val_loss: 2.3672 - val_accuracy: 0.6102 - 2s/epoch - 108ms/step
# Epoch 126/200
# 15/15 - 2s - loss: 0.0077 - accuracy: 0.9979 - val_loss: 1.0320 - val_accuracy: 0.7797 - 2s/epoch - 107ms/step
# Epoch 127/200
# 15/15 - 2s - loss: 0.0085 - accuracy: 0.9979 - val_loss: 0.6918 - val_accuracy: 0.8136 - 2s/epoch - 107ms/step
# Epoch 128/200
# 15/15 - 2s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.7067 - val_accuracy: 0.8305 - 2s/epoch - 108ms/step
# Epoch 129/200
# 15/15 - 2s - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.6963 - val_accuracy: 0.8305 - 2s/epoch - 107ms/step
# Epoch 130/200
# 15/15 - 2s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6403 - val_accuracy: 0.8644 - 2s/epoch - 108ms/step
# Epoch 131/200
# 15/15 - 2s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.6066 - val_accuracy: 0.8814 - 2s/epoch - 107ms/step
# Epoch 132/200
# 15/15 - 2s - loss: 7.6521e-04 - accuracy: 1.0000 - val_loss: 0.6221 - val_accuracy: 0.8305 - 2s/epoch - 107ms/step
# Epoch 133/200
# 15/15 - 2s - loss: 6.5935e-04 - accuracy: 1.0000 - val_loss: 0.6014 - val_accuracy: 0.8644 - 2s/epoch - 108ms/step
# Epoch 134/200
# 15/15 - 2s - loss: 7.8444e-04 - accuracy: 1.0000 - val_loss: 0.5765 - val_accuracy: 0.8983 - 2s/epoch - 108ms/step
# Epoch 135/200
# 15/15 - 2s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5477 - val_accuracy: 0.9153 - 2s/epoch - 108ms/step
# Epoch 136/200
# 15/15 - 2s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5652 - val_accuracy: 0.8814 - 2s/epoch - 108ms/step
# Epoch 137/200
# 15/15 - 2s - loss: 0.0126 - accuracy: 0.9937 - val_loss: 0.7158 - val_accuracy: 0.8136 - 2s/epoch - 108ms/step
# Epoch 138/200
# 15/15 - 2s - loss: 0.0113 - accuracy: 0.9958 - val_loss: 0.6217 - val_accuracy: 0.8475 - 2s/epoch - 107ms/step
# Epoch 139/200
# 15/15 - 2s - loss: 0.0179 - accuracy: 0.9937 - val_loss: 1.9698 - val_accuracy: 0.6102 - 2s/epoch - 108ms/step
# Epoch 140/200
# 15/15 - 2s - loss: 0.0177 - accuracy: 0.9937 - val_loss: 2.4227 - val_accuracy: 0.5932 - 2s/epoch - 108ms/step
# Epoch 141/200
# 15/15 - 2s - loss: 0.0384 - accuracy: 0.9915 - val_loss: 2.0032 - val_accuracy: 0.7119 - 2s/epoch - 109ms/step
# Epoch 142/200
# 15/15 - 2s - loss: 0.0107 - accuracy: 0.9958 - val_loss: 3.9864 - val_accuracy: 0.4746 - 2s/epoch - 108ms/step
# Epoch 143/200
# 15/15 - 2s - loss: 0.0211 - accuracy: 0.9979 - val_loss: 3.1427 - val_accuracy: 0.5254 - 2s/epoch - 108ms/step
# Epoch 144/200
# 15/15 - 2s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.8056 - val_accuracy: 0.6441 - 2s/epoch - 109ms/step
# Epoch 145/200
# 15/15 - 2s - loss: 0.0143 - accuracy: 0.9979 - val_loss: 2.0221 - val_accuracy: 0.6271 - 2s/epoch - 108ms/step
# Epoch 146/200
# 15/15 - 2s - loss: 0.0101 - accuracy: 0.9958 - val_loss: 1.9760 - val_accuracy: 0.6102 - 2s/epoch - 109ms/step
# Epoch 147/200
# 15/15 - 2s - loss: 0.0158 - accuracy: 0.9915 - val_loss: 1.9559 - val_accuracy: 0.6441 - 2s/epoch - 107ms/step
# Epoch 148/200
# 15/15 - 2s - loss: 0.0157 - accuracy: 0.9937 - val_loss: 1.5153 - val_accuracy: 0.6610 - 2s/epoch - 107ms/step
# Epoch 149/200
# 15/15 - 2s - loss: 0.0107 - accuracy: 0.9979 - val_loss: 0.9452 - val_accuracy: 0.7797 - 2s/epoch - 108ms/step
# Epoch 150/200
# 15/15 - 2s - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.6432 - val_accuracy: 0.8305 - 2s/epoch - 107ms/step
# Epoch 151/200
# 15/15 - 2s - loss: 0.0119 - accuracy: 0.9958 - val_loss: 2.6314 - val_accuracy: 0.5932 - 2s/epoch - 108ms/step
# Epoch 152/200
# 15/15 - 2s - loss: 0.0190 - accuracy: 0.9958 - val_loss: 1.9693 - val_accuracy: 0.6610 - 2s/epoch - 108ms/step
# Epoch 153/200
# 15/15 - 2s - loss: 0.0117 - accuracy: 0.9937 - val_loss: 3.2985 - val_accuracy: 0.5763 - 2s/epoch - 108ms/step
# Epoch 154/200
# 15/15 - 2s - loss: 0.0252 - accuracy: 0.9873 - val_loss: 3.4089 - val_accuracy: 0.5254 - 2s/epoch - 108ms/step
# Epoch 155/200
# 15/15 - 2s - loss: 0.0291 - accuracy: 0.9915 - val_loss: 1.5152 - val_accuracy: 0.6949 - 2s/epoch - 108ms/step
# Epoch 156/200
# 15/15 - 2s - loss: 0.0340 - accuracy: 0.9873 - val_loss: 1.8087 - val_accuracy: 0.6610 - 2s/epoch - 108ms/step
# Epoch 157/200
# 15/15 - 2s - loss: 0.0340 - accuracy: 0.9852 - val_loss: 1.8590 - val_accuracy: 0.7288 - 2s/epoch - 108ms/step
# Epoch 158/200
# 15/15 - 2s - loss: 0.0468 - accuracy: 0.9894 - val_loss: 1.3685 - val_accuracy: 0.7627 - 2s/epoch - 108ms/step
# Epoch 159/200
# 15/15 - 2s - loss: 0.0403 - accuracy: 0.9810 - val_loss: 3.7236 - val_accuracy: 0.4576 - 2s/epoch - 109ms/step
# Epoch 160/200
# 15/15 - 2s - loss: 0.0481 - accuracy: 0.9852 - val_loss: 4.1812 - val_accuracy: 0.5085 - 2s/epoch - 109ms/step
# Epoch 161/200
# 15/15 - 2s - loss: 0.0243 - accuracy: 0.9894 - val_loss: 2.7069 - val_accuracy: 0.6102 - 2s/epoch - 108ms/step
# Epoch 162/200
# 15/15 - 2s - loss: 0.0503 - accuracy: 0.9810 - val_loss: 1.6145 - val_accuracy: 0.6949 - 2s/epoch - 109ms/step
# Epoch 163/200
# 15/15 - 2s - loss: 0.0606 - accuracy: 0.9852 - val_loss: 0.8963 - val_accuracy: 0.7966 - 2s/epoch - 108ms/step
# Epoch 164/200
# 15/15 - 2s - loss: 0.0530 - accuracy: 0.9767 - val_loss: 0.8866 - val_accuracy: 0.7797 - 2s/epoch - 108ms/step
# Epoch 165/200
# 15/15 - 2s - loss: 0.0301 - accuracy: 0.9915 - val_loss: 1.3727 - val_accuracy: 0.7627 - 2s/epoch - 109ms/step
# Epoch 166/200
# 15/15 - 2s - loss: 0.0218 - accuracy: 0.9937 - val_loss: 1.1988 - val_accuracy: 0.7627 - 2s/epoch - 108ms/step
# Epoch 167/200
# 15/15 - 2s - loss: 0.0071 - accuracy: 0.9979 - val_loss: 0.9977 - val_accuracy: 0.8136 - 2s/epoch - 109ms/step
# Epoch 168/200
# 15/15 - 2s - loss: 0.0096 - accuracy: 0.9979 - val_loss: 1.0408 - val_accuracy: 0.7627 - 2s/epoch - 108ms/step
# Epoch 169/200
# 15/15 - 2s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.3798 - val_accuracy: 0.7288 - 2s/epoch - 107ms/step
# Epoch 170/200
# 15/15 - 2s - loss: 0.0132 - accuracy: 0.9937 - val_loss: 0.8632 - val_accuracy: 0.7627 - 2s/epoch - 108ms/step
# Epoch 171/200
# 15/15 - 2s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.9280 - val_accuracy: 0.7627 - 2s/epoch - 108ms/step
# Epoch 172/200
# 15/15 - 2s - loss: 0.0081 - accuracy: 0.9937 - val_loss: 0.9576 - val_accuracy: 0.7797 - 2s/epoch - 108ms/step
# Epoch 173/200
# 15/15 - 2s - loss: 0.0041 - accuracy: 0.9979 - val_loss: 0.7971 - val_accuracy: 0.7797 - 2s/epoch - 108ms/step
# Epoch 174/200
# 15/15 - 2s - loss: 0.0138 - accuracy: 0.9979 - val_loss: 0.7546 - val_accuracy: 0.8136 - 2s/epoch - 108ms/step
# Epoch 175/200
# 15/15 - 2s - loss: 0.0060 - accuracy: 1.0000 - val_loss: 1.0872 - val_accuracy: 0.7627 - 2s/epoch - 108ms/step
# Epoch 176/200
# 15/15 - 2s - loss: 0.0193 - accuracy: 0.9937 - val_loss: 0.9278 - val_accuracy: 0.7966 - 2s/epoch - 109ms/step
# Epoch 177/200
# 15/15 - 2s - loss: 0.0466 - accuracy: 0.9894 - val_loss: 1.2989 - val_accuracy: 0.6949 - 2s/epoch - 108ms/step
# Epoch 178/200
# 15/15 - 2s - loss: 0.0073 - accuracy: 0.9979 - val_loss: 2.1156 - val_accuracy: 0.6271 - 2s/epoch - 108ms/step
# Epoch 179/200
# 15/15 - 2s - loss: 0.0095 - accuracy: 0.9979 - val_loss: 1.4553 - val_accuracy: 0.6949 - 2s/epoch - 108ms/step
# Epoch 180/200
# 15/15 - 2s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 1.1937 - val_accuracy: 0.7119 - 2s/epoch - 108ms/step
# Epoch 181/200
# 15/15 - 2s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.0432 - val_accuracy: 0.7458 - 2s/epoch - 108ms/step
# Epoch 182/200
# 15/15 - 2s - loss: 9.6043e-04 - accuracy: 1.0000 - val_loss: 0.8947 - val_accuracy: 0.7627 - 2s/epoch - 108ms/step
# Epoch 183/200
# 15/15 - 2s - loss: 5.2820e-04 - accuracy: 1.0000 - val_loss: 0.8140 - val_accuracy: 0.7966 - 2s/epoch - 109ms/step
# Epoch 184/200
# 15/15 - 2s - loss: 0.0254 - accuracy: 0.9937 - val_loss: 0.7542 - val_accuracy: 0.8305 - 2s/epoch - 108ms/step
# Epoch 185/200
# 15/15 - 2s - loss: 0.0146 - accuracy: 0.9958 - val_loss: 1.0779 - val_accuracy: 0.7797 - 2s/epoch - 108ms/step
# Epoch 186/200
# 15/15 - 2s - loss: 0.0285 - accuracy: 0.9894 - val_loss: 2.4608 - val_accuracy: 0.6949 - 2s/epoch - 108ms/step
# Epoch 187/200
# 15/15 - 2s - loss: 0.0064 - accuracy: 0.9979 - val_loss: 2.8322 - val_accuracy: 0.6610 - 2s/epoch - 109ms/step
# Epoch 188/200
# 15/15 - 2s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 2.7508 - val_accuracy: 0.6441 - 2s/epoch - 108ms/step
# Epoch 189/200
# 15/15 - 2s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 1.7372 - val_accuracy: 0.7458 - 2s/epoch - 108ms/step
# Epoch 190/200
# 15/15 - 2s - loss: 9.3349e-04 - accuracy: 1.0000 - val_loss: 0.9821 - val_accuracy: 0.8475 - 2s/epoch - 108ms/step
# Epoch 191/200
# 15/15 - 2s - loss: 0.0043 - accuracy: 0.9979 - val_loss: 0.8420 - val_accuracy: 0.8305 - 2s/epoch - 108ms/step
# Epoch 192/200
# 15/15 - 2s - loss: 0.0190 - accuracy: 0.9958 - val_loss: 3.8056 - val_accuracy: 0.5593 - 2s/epoch - 107ms/step
# Epoch 193/200
# 15/15 - 2s - loss: 0.0619 - accuracy: 0.9831 - val_loss: 1.1832 - val_accuracy: 0.6610 - 2s/epoch - 108ms/step
# Epoch 194/200
# 15/15 - 2s - loss: 0.0332 - accuracy: 0.9852 - val_loss: 2.3849 - val_accuracy: 0.5424 - 2s/epoch - 107ms/step
# Epoch 195/200
# 15/15 - 2s - loss: 0.0246 - accuracy: 0.9937 - val_loss: 1.8602 - val_accuracy: 0.6610 - 2s/epoch - 108ms/step
# Epoch 196/200
# 15/15 - 2s - loss: 0.0193 - accuracy: 0.9937 - val_loss: 1.4982 - val_accuracy: 0.6780 - 2s/epoch - 108ms/step
# Epoch 197/200
# 15/15 - 2s - loss: 0.0229 - accuracy: 0.9915 - val_loss: 1.3699 - val_accuracy: 0.6949 - 2s/epoch - 108ms/step
# Epoch 198/200
# 15/15 - 2s - loss: 0.0089 - accuracy: 0.9958 - val_loss: 1.1433 - val_accuracy: 0.7458 - 2s/epoch - 108ms/step
# Epoch 199/200
# 15/15 - 2s - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.9819 - val_accuracy: 0.7288 - 2s/epoch - 108ms/step
# Epoch 200/200
# 15/15 - 2s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.0044 - val_accuracy: 0.7627 - 2s/epoch - 109ms/step

# %%
 # evaluate model
_, acc = model.evaluate(testX, testY, verbose=verb)
print('Acurácia: %.3f' % (acc * 100.0))
# Out:
# 2/2 - 0s - loss: 1.0044 - accuracy: 0.7627 - 78ms/epoch - 39ms/step
# Acurácia: 76.271

# %%
 # learning curves
summarize_diagnostics(history)

# %%
model_name = f'displasys-mobilenet-baseline-holdout-{epochs}epochs_batch_transferlearning.npy'
model.save(model_name)
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) mobilenet_1.00_128_input with unsupported characters which will be renamed to mobilenet_1_00_128_input in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 29). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: displasys-mobilenet-baseline-holdout-200epochs_batch_transferlearning.npy\assets
# INFO:tensorflow:Assets written to: displasys-mobilenet-baseline-holdout-200epochs_batch_transferlearning.npy\assets

# %%
# entry point, run the test harness
#run_test_harness(epochs=100, verb=1)
