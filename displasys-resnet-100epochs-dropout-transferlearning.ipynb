# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
import time
import numpy as np

# %%
# baseline model with dropout and data augmentation on the cifar10 dataset
import sys
from matplotlib import pyplot
from keras.datasets import cifar10
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dropout
from keras.layers import BatchNormalization

# %%
# load train and test dataset
def load_dataset():
    # load dataset
    data_x = np.load('data_x_original.npy')
    data_y = np.load('data_y_original.npy')
    #percentage of the dataset which will be on TRAIN - TEST - VALIDATION
    TOTAL_IMAGES = len(data_y)
    print("TOTAL_IMAGES = ", TOTAL_IMAGES)
    
    TRAIN_PERCENTAGE = 0.8
    TEST_PERCENTAGE = 0.1
    VALIDATION_PERCENTAGE = 0.1

    train_size = int(TRAIN_PERCENTAGE * TOTAL_IMAGES)
    test_size = int(TEST_PERCENTAGE * TOTAL_IMAGES)
    validation_size = int(VALIDATION_PERCENTAGE * TOTAL_IMAGES)

    train_x = data_x[:train_size] #taking train images from original data
    train_y = data_y[:train_size]
    data_x = data_x[train_size:] #removing train images from original data
    data_y = data_y[train_size:]

    test_x = data_x[:test_size] #taking test images from original data
    test_y = data_y[:test_size]
    data_x = data_x[test_size:] #removing test images from original data
    data_y = data_y[test_size:]

    validation_x = data_x #all the remainder images we can put on validation
    validation_y = data_y

    del data_x #free some unused memory
    del data_y

    print("train_size = ", len(train_y))
    print("test_size = ", len(test_y))
    print("validation_size = ", len(validation_y))
 # one hot encode target values
    train_y = to_categorical(train_y)
    test_y = to_categorical(test_y)
    validation_y = to_categorical(validation_y)
    return train_x, train_y, test_x, test_y, validation_x, validation_y

# %%
# scale pixels
def prep_pixels(train, test, validation):
 # convert from integers to floats
 train_norm = train.astype('float32')
 test_norm = test.astype('float32')
 validation_norm = validation.astype('float32')
 # normalize to range 0-1
 train_norm = train_norm / 255.0
 test_norm = test_norm / 255.0
 validation_norm = validation_norm / 255.0
 # return normalized images
 return train_norm, test_norm, validation_norm

# %%
# define cnn model
def define_model():
    new_model = Sequential()
    
    model = tf.keras.applications.ResNet50(
        include_top=False,
        weights='imagenet',
        input_tensor=None,
        input_shape=(128,128,3),
        pooling=None,
        classes=4,
       # classifier_activation="softmax",
    #    **kwargs
        )
    
    new_model.add(model)
    #3rd conv layer
    new_model.add(tf.keras.layers.Conv2D(32, 3, padding="same"))
    #new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.MaxPooling2D(2, padding='same'))
    new_model.add(tf.keras.layers.Dropout(0.2))
    #4th conv layer
    new_model.add(tf.keras.layers.Conv2D(64, 3, padding="same"))
    #new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    new_model.add(tf.keras.layers.MaxPooling2D(2, padding='same'))
    #new_model.add(tf.keras.layers.Dropout(0.2))
    #Flatten Layer
    new_model.add(tf.keras.layers.Flatten())

    new_model.add(tf.keras.layers.Dense(128))
    #new_model.add(tf.keras.layers.BatchNormalization())
    new_model.add(tf.keras.layers.Activation("relu"))
    #new_model.add(tf.keras.layers.Dropout(0.2))
    #output Dense Layer
    new_model.add(tf.keras.layers.Dense(4))
    new_model.add(tf.keras.layers.Activation('softmax'))
    
    opt = SGD(lr=0.001, momentum=0.9)
    new_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    return new_model

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
 # plot loss
    model_trained = history
    accuracy = model_trained.history['accuracy']
    val_accuracy = model_trained.history['val_accuracy']
    loss = model_trained.history['loss']
    val_loss = model_trained.history['val_loss']
    epochs = range(len(accuracy))
    plt.plot(epochs, accuracy, 'b', label='Acurácia de treino')
    plt.plot(epochs, val_accuracy, 'g', label='Acurácia de validação')
    plt.title('Acurácia de treino e validação')
    plt.legend()
    plt.figure()
    plt.plot(epochs, loss, 'b', label='Perda no treino')
    plt.plot(epochs, val_loss, 'g', label='Perda na validação')
    plt.title('Perda na validação e treino')
    plt.legend()
    plt.show()

# %%
epochs = 100
verb = 2

# %%
trainX, trainY, testX, testY, validationX, validationY = load_dataset()
 # prepare pixel data
trainX, testX, validationX = prep_pixels(trainX, testX, validationX)
 # define model
model = define_model()

history = model.fit(trainX, trainY, epochs=epochs, validation_data=(validationX, validationY), verbose=verb)
# Out:
# TOTAL_IMAGES =  592
# train_size =  473
# test_size =  59
# validation_size =  60
# Epoch 1/100
# 15/15 - 19s - loss: 1.5408 - accuracy: 0.2600 - val_loss: 1.3851 - val_accuracy: 0.2167 - 19s/epoch - 1s/step
# Epoch 2/100
# 15/15 - 4s - loss: 1.2259 - accuracy: 0.4461 - val_loss: 1.4182 - val_accuracy: 0.2167 - 4s/epoch - 286ms/step
# Epoch 3/100
# 15/15 - 4s - loss: 1.0463 - accuracy: 0.5772 - val_loss: 1.4021 - val_accuracy: 0.2667 - 4s/epoch - 286ms/step
# Epoch 4/100
# 15/15 - 4s - loss: 0.7586 - accuracy: 0.7061 - val_loss: 2.1853 - val_accuracy: 0.2667 - 4s/epoch - 286ms/step
# Epoch 5/100
# 15/15 - 4s - loss: 0.5431 - accuracy: 0.8034 - val_loss: 3.4560 - val_accuracy: 0.2667 - 4s/epoch - 286ms/step
# Epoch 6/100
# 15/15 - 4s - loss: 0.3558 - accuracy: 0.8774 - val_loss: 4.7745 - val_accuracy: 0.2667 - 4s/epoch - 286ms/step
# Epoch 7/100
# 15/15 - 4s - loss: 0.1941 - accuracy: 0.9450 - val_loss: 10.1057 - val_accuracy: 0.2667 - 4s/epoch - 286ms/step
# Epoch 8/100
# 15/15 - 4s - loss: 0.1291 - accuracy: 0.9704 - val_loss: 14.1729 - val_accuracy: 0.2667 - 4s/epoch - 286ms/step
# Epoch 9/100
# 15/15 - 4s - loss: 0.0818 - accuracy: 0.9725 - val_loss: 15.3265 - val_accuracy: 0.2667 - 4s/epoch - 285ms/step
# Epoch 10/100
# 15/15 - 4s - loss: 0.0508 - accuracy: 0.9894 - val_loss: 20.3655 - val_accuracy: 0.2667 - 4s/epoch - 286ms/step
# Epoch 11/100
# 15/15 - 4s - loss: 0.0489 - accuracy: 0.9894 - val_loss: 18.0137 - val_accuracy: 0.2667 - 4s/epoch - 286ms/step
# Epoch 12/100
# 15/15 - 4s - loss: 0.0473 - accuracy: 0.9915 - val_loss: 23.6164 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 13/100
# 15/15 - 4s - loss: 0.0257 - accuracy: 0.9937 - val_loss: 35.0895 - val_accuracy: 0.2667 - 4s/epoch - 286ms/step
# Epoch 14/100
# 15/15 - 4s - loss: 0.0352 - accuracy: 0.9873 - val_loss: 34.9968 - val_accuracy: 0.2667 - 4s/epoch - 286ms/step
# Epoch 15/100
# 15/15 - 4s - loss: 0.0161 - accuracy: 0.9979 - val_loss: 48.3852 - val_accuracy: 0.2667 - 4s/epoch - 286ms/step
# Epoch 16/100
# 15/15 - 4s - loss: 0.0162 - accuracy: 0.9979 - val_loss: 57.6595 - val_accuracy: 0.2667 - 4s/epoch - 287ms/step
# Epoch 17/100
# 15/15 - 4s - loss: 0.0258 - accuracy: 0.9894 - val_loss: 62.2575 - val_accuracy: 0.2667 - 4s/epoch - 287ms/step
# Epoch 18/100
# 15/15 - 4s - loss: 0.0134 - accuracy: 0.9979 - val_loss: 71.2953 - val_accuracy: 0.2667 - 4s/epoch - 287ms/step
# Epoch 19/100
# 15/15 - 4s - loss: 0.0143 - accuracy: 0.9979 - val_loss: 71.8639 - val_accuracy: 0.2667 - 4s/epoch - 287ms/step
# Epoch 20/100
# 15/15 - 4s - loss: 0.0076 - accuracy: 0.9979 - val_loss: 76.5258 - val_accuracy: 0.2667 - 4s/epoch - 287ms/step
# Epoch 21/100
# 15/15 - 4s - loss: 0.0173 - accuracy: 0.9937 - val_loss: 72.4746 - val_accuracy: 0.2667 - 4s/epoch - 287ms/step
# Epoch 22/100
# 15/15 - 4s - loss: 0.0116 - accuracy: 0.9979 - val_loss: 66.3398 - val_accuracy: 0.2667 - 4s/epoch - 287ms/step
# Epoch 23/100
# 15/15 - 4s - loss: 0.0123 - accuracy: 0.9979 - val_loss: 75.3340 - val_accuracy: 0.2667 - 4s/epoch - 286ms/step
# Epoch 24/100
# 15/15 - 4s - loss: 0.0044 - accuracy: 1.0000 - val_loss: 77.1581 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 25/100
# 15/15 - 4s - loss: 0.0161 - accuracy: 0.9958 - val_loss: 62.4139 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 26/100
# 15/15 - 4s - loss: 0.0126 - accuracy: 0.9979 - val_loss: 64.5732 - val_accuracy: 0.2667 - 4s/epoch - 287ms/step
# Epoch 27/100
# 15/15 - 4s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 64.7757 - val_accuracy: 0.2667 - 4s/epoch - 287ms/step
# Epoch 28/100
# 15/15 - 4s - loss: 0.0045 - accuracy: 1.0000 - val_loss: 65.3918 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 29/100
# 15/15 - 4s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 64.9335 - val_accuracy: 0.2667 - 4s/epoch - 287ms/step
# Epoch 30/100
# 15/15 - 4s - loss: 0.0073 - accuracy: 0.9958 - val_loss: 65.2626 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 31/100
# 15/15 - 4s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 66.3997 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 32/100
# 15/15 - 4s - loss: 0.0049 - accuracy: 1.0000 - val_loss: 68.4574 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 33/100
# 15/15 - 4s - loss: 0.0056 - accuracy: 0.9979 - val_loss: 67.1829 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 34/100
# 15/15 - 4s - loss: 0.0082 - accuracy: 0.9979 - val_loss: 62.9015 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 35/100
# 15/15 - 4s - loss: 0.0065 - accuracy: 0.9979 - val_loss: 60.8106 - val_accuracy: 0.2667 - 4s/epoch - 290ms/step
# Epoch 36/100
# 15/15 - 4s - loss: 0.0071 - accuracy: 0.9979 - val_loss: 66.8471 - val_accuracy: 0.2667 - 4s/epoch - 292ms/step
# Epoch 37/100
# 15/15 - 4s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 67.0203 - val_accuracy: 0.2667 - 4s/epoch - 290ms/step
# Epoch 38/100
# 15/15 - 4s - loss: 0.0058 - accuracy: 0.9979 - val_loss: 68.0610 - val_accuracy: 0.2667 - 4s/epoch - 291ms/step
# Epoch 39/100
# 15/15 - 4s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 74.4576 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 40/100
# 15/15 - 4s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 80.3042 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 41/100
# 15/15 - 4s - loss: 0.0059 - accuracy: 0.9979 - val_loss: 71.4602 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 42/100
# 15/15 - 4s - loss: 0.0048 - accuracy: 0.9979 - val_loss: 69.9886 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 43/100
# 15/15 - 4s - loss: 0.0033 - accuracy: 0.9979 - val_loss: 69.7528 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 44/100
# 15/15 - 4s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 70.6733 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 45/100
# 15/15 - 4s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 70.3077 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 46/100
# 15/15 - 4s - loss: 0.0029 - accuracy: 1.0000 - val_loss: 68.5490 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 47/100
# 15/15 - 4s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 67.9147 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 48/100
# 15/15 - 4s - loss: 0.0054 - accuracy: 1.0000 - val_loss: 64.8140 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 49/100
# 15/15 - 4s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 65.2135 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 50/100
# 15/15 - 4s - loss: 0.0027 - accuracy: 1.0000 - val_loss: 75.4935 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 51/100
# 15/15 - 4s - loss: 0.0071 - accuracy: 0.9958 - val_loss: 62.8898 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 52/100
# 15/15 - 4s - loss: 7.0503e-04 - accuracy: 1.0000 - val_loss: 62.0178 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 53/100
# 15/15 - 4s - loss: 0.0052 - accuracy: 0.9979 - val_loss: 62.7158 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 54/100
# 15/15 - 4s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 64.2717 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 55/100
# 15/15 - 4s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 70.7926 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 56/100
# 15/15 - 4s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 73.5380 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 57/100
# 15/15 - 4s - loss: 0.0054 - accuracy: 0.9979 - val_loss: 67.6390 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 58/100
# 15/15 - 4s - loss: 0.0132 - accuracy: 0.9937 - val_loss: 52.4003 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 59/100
# 15/15 - 4s - loss: 0.0118 - accuracy: 0.9979 - val_loss: 59.8371 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 60/100
# 15/15 - 4s - loss: 0.0084 - accuracy: 0.9958 - val_loss: 52.0288 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 61/100
# 15/15 - 4s - loss: 0.0045 - accuracy: 0.9979 - val_loss: 51.3238 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 62/100
# 15/15 - 4s - loss: 0.0025 - accuracy: 0.9979 - val_loss: 54.2823 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 63/100
# 15/15 - 4s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 54.5871 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 64/100
# 15/15 - 4s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 54.8623 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 65/100
# 15/15 - 4s - loss: 0.0050 - accuracy: 1.0000 - val_loss: 59.0214 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 66/100
# 15/15 - 4s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 60.5071 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 67/100
# 15/15 - 4s - loss: 0.0035 - accuracy: 0.9979 - val_loss: 63.1229 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 68/100
# 15/15 - 4s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 67.1222 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 69/100
# 15/15 - 4s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 68.5543 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 70/100
# 15/15 - 4s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 71.0711 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 71/100
# 15/15 - 4s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 72.7710 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 72/100
# 15/15 - 4s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 74.1700 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 73/100
# 15/15 - 4s - loss: 4.3580e-04 - accuracy: 1.0000 - val_loss: 76.5969 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 74/100
# 15/15 - 4s - loss: 0.0036 - accuracy: 1.0000 - val_loss: 85.4021 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 75/100
# 15/15 - 4s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 86.7000 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 76/100
# 15/15 - 4s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 85.1190 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 77/100
# 15/15 - 4s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 82.5969 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 78/100
# 15/15 - 4s - loss: 0.0024 - accuracy: 0.9979 - val_loss: 78.7240 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 79/100
# 15/15 - 4s - loss: 7.6615e-04 - accuracy: 1.0000 - val_loss: 75.2848 - val_accuracy: 0.2667 - 4s/epoch - 290ms/step
# Epoch 80/100
# 15/15 - 4s - loss: 0.0115 - accuracy: 0.9979 - val_loss: 53.7389 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 81/100
# 15/15 - 4s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 43.8384 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 82/100
# 15/15 - 4s - loss: 0.0045 - accuracy: 0.9979 - val_loss: 46.4681 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 83/100
# 15/15 - 4s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 53.7520 - val_accuracy: 0.2667 - 4s/epoch - 288ms/step
# Epoch 84/100
# 15/15 - 4s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 55.3254 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 85/100
# 15/15 - 4s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 52.5145 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 86/100
# 15/15 - 4s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 52.3862 - val_accuracy: 0.2667 - 4s/epoch - 289ms/step
# Epoch 87/100
# 15/15 - 4s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 52.7715 - val_accuracy: 0.2667 - 4s/epoch - 291ms/step
# Epoch 88/100
# 15/15 - 4s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 52.1845 - val_accuracy: 0.2667 - 4s/epoch - 290ms/step
# Epoch 89/100
# 15/15 - 4s - loss: 5.9394e-04 - accuracy: 1.0000 - val_loss: 50.7108 - val_accuracy: 0.2667 - 4s/epoch - 291ms/step
# Epoch 90/100
# 15/15 - 4s - loss: 9.3611e-04 - accuracy: 1.0000 - val_loss: 48.7948 - val_accuracy: 0.2667 - 4s/epoch - 290ms/step
# Epoch 91/100
# 15/15 - 4s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 47.5908 - val_accuracy: 0.2667 - 4s/epoch - 291ms/step
# Epoch 92/100
# 15/15 - 4s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 45.3738 - val_accuracy: 0.2667 - 4s/epoch - 290ms/step
# Epoch 93/100
# 15/15 - 4s - loss: 0.0045 - accuracy: 0.9979 - val_loss: 40.7528 - val_accuracy: 0.2667 - 4s/epoch - 291ms/step
# Epoch 94/100
# 15/15 - 4s - loss: 0.0096 - accuracy: 0.9979 - val_loss: 37.9730 - val_accuracy: 0.2667 - 4s/epoch - 291ms/step
# Epoch 95/100
# 15/15 - 4s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 36.6650 - val_accuracy: 0.2667 - 4s/epoch - 292ms/step
# Epoch 96/100
# 15/15 - 4s - loss: 0.0036 - accuracy: 0.9979 - val_loss: 34.0791 - val_accuracy: 0.2667 - 4s/epoch - 291ms/step
# Epoch 97/100
# 15/15 - 4s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 31.6632 - val_accuracy: 0.2667 - 4s/epoch - 292ms/step
# Epoch 98/100
# 15/15 - 4s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 27.1950 - val_accuracy: 0.2667 - 4s/epoch - 290ms/step
# Epoch 99/100
# 15/15 - 4s - loss: 3.5130e-04 - accuracy: 1.0000 - val_loss: 24.2794 - val_accuracy: 0.2667 - 4s/epoch - 292ms/step
# Epoch 100/100
# 15/15 - 4s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 22.0057 - val_accuracy: 0.2667 - 4s/epoch - 292ms/step

# %%
 # evaluate model
_, acc = model.evaluate(testX, testY, verbose=verb)
print('Acurácia: %.3f' % (acc * 100.0))
# Out:
# 2/2 - 1s - loss: 20.8310 - accuracy: 0.3390 - 659ms/epoch - 329ms/step
# Acurácia: 33.898

# %%
 # learning curves
summarize_diagnostics(history)

# %%
model_name = f'displasys-resnet50-baseline-holdout-{epochs}epochs_dropout_transferlearning.npy'
model.save(model_name)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 55). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: displasys-resnet50-baseline-holdout-100epochs_dropout_transferlearning.npy\assets
# INFO:tensorflow:Assets written to: displasys-resnet50-baseline-holdout-100epochs_dropout_transferlearning.npy\assets

# %%
# entry point, run the test harness
#run_test_harness(epochs=100, verb=1)
